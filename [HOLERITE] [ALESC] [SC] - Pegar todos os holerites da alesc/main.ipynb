# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def extrair_detalhes_holerite(session, url_remun, nome_servidor):
    try:
        response = session.get(url_remun, timeout=15)
        response.encoding = 'iso-8859-1'
        soup = BeautifulSoup(response.text, 'html.parser')
        
        detalhes = {}
        tabela = soup.find('table', class_='detalhe-contracheque')
        
        if not tabela:
            print(f"    ⚠ Tabela não encontrada para: {nome_servidor}")
            return detalhes
        
        secao_atual = ''
        
        for linha in tabela.find_all('tr'):
            classes = linha.get('class', [])
            cols = linha.find_all('td')
            if not cols:
                continue
            
            # ✅ BRUTO e LÍQUIDO ficam na própria linha de seção — extrair o valor corretamente
            if 'bruto' in classes or 'liquido' in classes:
                nome_campo = cols[0].get_text(strip=True)    # "BRUTO" ou "LÍQUIDO"
                valor = cols[1].get_text(strip=True) if len(cols) > 1 else ''
                detalhes[nome_campo] = valor
                # Itens que vêm após o BRUTO são descontos (Previdência, IR...)
                if 'bruto' in classes:
                    secao_atual = 'Descontos'
                continue
            
            # Demais linhas de seção (títulos de grupo de provento)
            if 'secao' in classes:
                secao_atual = cols[0].get_text(strip=True)
                continue
            
            # Linha de dados normal: [campo] [Mês Atual] [Atrasados]
            if len(cols) >= 2:
                chave = cols[0].get_text(strip=True)
                if not chave or chave == '&nbsp;':
                    continue
                
                valor_mes      = cols[1].get_text(strip=True) if len(cols) > 1 else ''
                valor_atrasado = cols[2].get_text(strip=True) if len(cols) > 2 else ''
                
                prefixo = f"{secao_atual} - " if secao_atual else ''
                chave_mes = f"{prefixo}{chave}"
                
                if valor_mes and valor_mes != '-':
                    detalhes[chave_mes] = valor_mes
                
                # Coluna de atrasados só aparece se tiver valor real
                if valor_atrasado and valor_atrasado != '-':
                    detalhes[f"{chave_mes} (Atrasados)"] = valor_atrasado
        
        bruto   = detalhes.get('BRUTO', '?')
        liquido = detalhes.get('LÍQUIDO', '?')
        print(f"    ✔ OK — {len(detalhes)} campos | Bruto: {bruto} | Líquido: {liquido}")
        return detalhes
    
    except Exception as e:
        print(f"    ✖ Erro ao acessar holerite de {nome_servidor}: {e}")
        return {}


def executar_scraping():
    base_url = "https://transparencia.alesc.sc.gov.br/"
    lista_final = []
    total_paginas = 138
    erros_pagina  = 0
    erros_holerite = 0
    
    session = requests.Session()
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/120.0.0.0 Safari/537.36'
    })

    print("=" * 60)
    print("INICIANDO SCRAPING — TRANSPARÊNCIA ALESC")
    print(f"Total de páginas a processar: {total_paginas}")
    print("=" * 60)

    for pagina in range(1, total_paginas + 1):
        print(f"\n[Pág {pagina:>3}/{total_paginas}] Buscando lista de servidores...")
        url_lista = f"{base_url}servidores.php?pagina={pagina}&nome=&vinculo=&setor_id=&modalidade="
        
        try:
            res = session.get(url_lista, timeout=15)
            res.encoding = 'iso-8859-1'
            soup = BeautifulSoup(res.text, 'html.parser')
            
            tabela_principal = soup.find('table', class_='pagamentos')
            if not tabela_principal:
                print(f"  ⚠ Tabela 'pagamentos' não encontrada — pulando página {pagina}")
                erros_pagina += 1
                continue
                
            linhas = tabela_principal.find_all('tr')[1:]
            print(f"  → {len(linhas)} servidores encontrados nesta página")

            for idx, linha in enumerate(linhas, start=1):
                cols = linha.find_all('td')
                if len(cols) >= 5:
                    nome   = cols[0].text.strip()
                    vinculo = cols[1].text.strip()
                    info = {
                        'Nome':    nome,
                        'Vínculo': vinculo,
                        'Lotação': cols[2].text.strip(),
                        'Regime':  cols[3].text.strip()
                    }
                    
                    link_tag = cols[4].find('a')
                    if link_tag:
                        href = link_tag['href']
                        url_holerite = f"{base_url}{href}"
                        print(f"  [{idx:>2}/{len(linhas)}] {nome[:40]:<40} | {vinculo[:20]}")
                        print(f"         URL: {url_holerite}")
                        dados_remuneracao = extrair_detalhes_holerite(session, url_holerite, nome)
                        if not dados_remuneracao:
                            erros_holerite += 1
                        info.update(dados_remuneracao)
                    else:
                        print(f"  [{idx:>2}/{len(linhas)}] {nome[:40]:<40} | sem link de remuneração")
                    
                    lista_final.append(info)
            
            print(f"  ✔ Página {pagina} concluída — total acumulado: {len(lista_final)} servidores")
            time.sleep(0.3)
            
        except Exception as e:
            print(f"  ✖ Erro na página {pagina}: {e}")
            erros_pagina += 1

    print("\n" + "=" * 60)
    print("EXPORTANDO DADOS...")
    
    df = pd.DataFrame(lista_final)
    
    # ✅ Ordenação de colunas por seção lógica
    # Seção 1 — Identificação
    cols_id = ['Nome', 'Vínculo', 'Lotação', 'Regime']
    # Seção 2 — Totalizadores (mais importantes, logo no início)
    cols_totais = ['BRUTO', 'LÍQUIDO']
    # Seção 3 — Rendimentos (todos os campos prefixados com "Rendimentos permanentes - ")
    cols_rendimentos = sorted([c for c in df.columns if c.startswith('Rendimentos permanentes')])
    # Seção 4 — Outros proventos
    cols_outros = sorted([c for c in df.columns if c.startswith('Outros')])
    # Seção 5 — Descontos (Previdência, IR etc.)
    cols_descontos = sorted([c for c in df.columns if c.startswith('Descontos')])
    # Demais colunas não categorizadas
    todas_mapeadas = set(cols_id + cols_totais + cols_rendimentos + cols_outros + cols_descontos)
    cols_resto = [c for c in df.columns if c not in todas_mapeadas]
    
    cols_ordenadas = (
        [c for c in cols_id     if c in df.columns] +
        [c for c in cols_totais if c in df.columns] +
        cols_rendimentos +
        cols_outros +
        cols_descontos +
        cols_resto
    )
    df = df[cols_ordenadas]
    
    df.to_csv('relatorio_completo_alesc.csv', index=False, encoding='utf-8-sig')
    
    print("=" * 60)
    print(f"✔ Arquivo 'relatorio_completo_alesc.csv' criado com sucesso!")
    print(f"  Total de servidores exportados : {len(lista_final)}")
    print(f"  Total de colunas               : {len(df.columns)}")
    print(f"  Erros em páginas               : {erros_pagina}")
    print(f"  Holerites sem dados            : {erros_holerite}")
    print("=" * 60)

executar_scraping()
# Out:
# ============================================================
# INICIANDO SCRAPING — TRANSPARÊNCIA ALESC
# Total de páginas a processar: 138
# ============================================================
#
# [Pág   1/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] ABEL VEIGA                               | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=G18P
#     ✔ OK — 7 campos | Bruto: 5.652,53 | Líquido: 4.806,96
#   [ 2/20] ABRAHAO MUSSI FILHO                      | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=od1x
#     ✔ OK — 6 campos | Bruto: 1.621,33 | Líquido: 1.451,10
#   [ 3/20] ACACIO JACQUES                           | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=OzA
#     ✔ OK — 7 campos | Bruto: 23.778,20 | Líquido: 21.635,84
#   [ 4/20] ACACIO MANOEL DA SILVA                   | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=QRkx
#     ⚠ Tabela não encontrada para: ACACIO MANOEL DA SILVA
#   [ 5/20] ACINDINO GRACILIANO DE QUADROS           | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=BVV
#     ✔ OK — 7 campos | Bruto: 21.583,29 | Líquido: 19.748,21
#   [ 6/20] ADA COELHO MIGNONI                       | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=BPo
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 28.016,59
#   [ 7/20] ADAIR BENJAMIN DE SOUZA                  | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=D18x
#     ✔ OK — 6 campos | Bruto: 2.304,37 | Líquido: 2.047,09
#   [ 8/20] ADAIR TRAINOTTI                          | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=GWvN
#     ⚠ Tabela não encontrada para: ADAIR TRAINOTTI
#   [ 9/20] ADAN POSSAMAI DELLA                      | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=aez9
#     ✔ OK — 7 campos | Bruto: 3.755,57 | Líquido: 3.253,03
#   [10/20] ADAO ARMANDO FEIJO                       | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=qXK9
#     ✔ OK — 4 campos | Bruto: 16.030,00 | Líquido: 12.697,46
#   [11/20] ADAO JOAO RODRIGUES                      | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=9zbN
#     ✔ OK — 6 campos | Bruto: 14.306,78 | Líquido: 10.642,69
#   [12/20] ADAO MOREIRA                             | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=BDzZ
#     ✔ OK — 7 campos | Bruto: 5.199,95 | Líquido: 4.598,86
#   [13/20] ADAURI ANTUNES BARBOSA                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=XnWK
#     ✔ OK — 7 campos | Bruto: 5.221,24 | Líquido: 4.403,90
#   [14/20] ADAURI PAULO SCHMITT                     | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=LK7
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 28.016,59
#   [15/20] ADELAIDE FURTADO VIEIRA                  | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=xDL
#     ✔ OK — 8 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   [16/20] ADELAR VIEIRA ALVES DA SILVA             | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=3v0X
#     ✔ OK — 5 campos | Bruto: 3.086,11 | Líquido: 2.827,19
#   [17/20] ADELCIO MACHADO DOS SANTOS               | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Vja
#     ✔ OK — 8 campos | Bruto: 11.947,27 | Líquido: 8.161,21
#   [18/20] ADELIA FERRARI CARDOSO                   | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=y1L3
#     ✔ OK — 7 campos | Bruto: 30.608,72 | Líquido: 27.510,08
#   [19/20] ADELIR BEZ LOPES                         | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=djP
#     ✔ OK — 7 campos | Bruto: 29.120,68 | Líquido: 29.120,68
#   [20/20] ADELIR DOS SANTOS MARTINS                | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=odLz
#     ✔ OK — 5 campos | Bruto: 1.621,33 | Líquido: 1.499,74
#   ✔ Página 1 concluída — total acumulado: 20 servidores
#
# [Pág   2/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] ADEMAR BERTAN                            | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=79q
#     ✔ OK — 8 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   [ 2/20] ADEMAR PAHL FILHO                        | -
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=YwMd
#     ✔ OK — 5 campos | Bruto: 4.283,49 | Líquido: 3.880,89
#   [ 3/20] ADEMIR BELONDINO DA SILVA                | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=KXR
#     ✔ OK — 7 campos | Bruto: 24.858,13 | Líquido: 22.564,58
#   [ 4/20] ADEMIR GASSTMANN                         | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=69o
#     ✔ OK — 9 campos | Bruto: 39.957,07 | Líquido: 35.549,67
#   [ 5/20] ADEMIR GONCALVES                         | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=E8MP
#     ✔ OK — 4 campos | Bruto: 10.337,06 | Líquido: 8.570,08
#   [ 6/20] ADEMIR PEREIRA                           | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=0av3
#     ⚠ Tabela não encontrada para: ADEMIR PEREIRA
#   [ 7/20] ADERBAL ZIN                              | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=DXx
#     ✔ OK — 6 campos | Bruto: 23.936,20 | Líquido: 21.771,72
#   [ 8/20] ADERLAN VIEIRA DA ROCHA                  | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=qdP0
#     ✔ OK — 7 campos | Bruto: 4.891,99 | Líquido: 4.177,32
#   [ 9/20] ADETERSON DAVID DOS PASSOS CRISPIM       | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ZBOD
#     ✔ OK — 9 campos | Bruto: 16.624,64 | Líquido: 11.014,87
#   [10/20] ADIEL FERNANDES CIPRIANO                 | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=kRz
#     ✔ OK — 12 campos | Bruto: 41.845,49 | Líquido: 27.545,14
#   [11/20] ADILIO DA SILVA FILHO                    | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=y6EN
#     ⚠ Tabela não encontrada para: ADILIO DA SILVA FILHO
#   [12/20] ADILOR GUGLIELMI                         | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=EWDZ
#     ✔ OK — 7 campos | Bruto: 12.270,05 | Líquido: 8.598,65
#   [13/20] ADILSON AGENOR PERES                     | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=DgN
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 27.493,00
#   [14/20] ADILSON GERSON GESSNER                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Do1p
#     ✔ OK — 5 campos | Bruto: 1.621,33 | Líquido: 1.499,74
#   [15/20] ADILSON HELIO DOS SANTOS                 | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=LLnd
#     ✔ OK — 7 campos | Bruto: 3.175,69 | Líquido: 1.847,46
#   [16/20] ADNILSON HOMEM BOTELHO                   | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=gkX6
#     ⚠ Tabela não encontrada para: ADNILSON HOMEM BOTELHO
#   [17/20] ADO STEINER                              | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=o8z
#     ✔ OK — 9 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   [18/20] ADOLAR UMLAUF                            | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=6OX9
#     ✔ OK — 5 campos | Bruto: 1.283,30 | Líquido: 1.187,06
#   [19/20] ADRIAN DE OLIVEIRA DA SILVA              | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=NG3m
#     ✔ OK — 7 campos | Bruto: 5.495,78 | Líquido: 3.107,06
#   [20/20] ADRIANA BACK KOERICH                     | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=D3YV
#     ✔ OK — 12 campos | Bruto: 41.845,49 | Líquido: 27.629,56
#   ✔ Página 2 concluída — total acumulado: 40 servidores
#
# [Pág   3/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] ADRIANA DE AZEVEDO SILVA                 | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=K3v0
#     ⚠ Tabela não encontrada para: ADRIANA DE AZEVEDO SILVA
#   [ 2/20] ADRIANA DILARA EGER                      | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Do17
#     ✔ OK — 5 campos | Bruto: 4.283,49 | Líquido: 3.880,89
#   [ 3/20] ADRIANA HELENA DE SOUSA GEZAK            | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=eo13
#     ✔ OK — 16 campos | Bruto: 34.843,76 | Líquido: 12.809,15
#   [ 4/20] ADRIANA IWERSEN DE SAO THIAGO            | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Kqm0
#     ✔ OK — 12 campos | Bruto: 27.834,28 | Líquido: 15.945,70
#   [ 5/20] ADRIANA LAUTH GUALBERTO                  | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=w18
#     ✔ OK — 7 campos | Bruto: 37.170,85 | Líquido: 33.153,52
#   [ 6/20] ADRIANA THAINA ROSSI                     | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Zz6L
#     ✔ OK — 5 campos | Bruto: 3.634,37 | Líquido: 3.309,66
#   [ 7/20] ADRIANA VIEIRA BRIGIDO                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Qbnk
#     ✔ OK — 9 campos | Bruto: 27.100,63 | Líquido: 16.689,36
#   [ 8/20] ADRIANE MACHADO FERRARI                  | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=EoVZ
#     ✔ OK — 7 campos | Bruto: 5.221,24 | Líquido: 4.609,55
#   [ 9/20] ADRIANO BENTA PINTO                      | Servidor à disposiçã
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=MM08
#     ⚠ Tabela não encontrada para: ADRIANO BENTA PINTO
#   [10/20] ADRIANO DE MARTINI                       | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=vo78
#     ✔ OK — 7 campos | Bruto: 9.435,91 | Líquido: 6.486,14
#   [11/20] ADRIANO GISLON                           | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=bxXm
#     ⚠ Tabela não encontrada para: ADRIANO GISLON
#   [12/20] ADRIANO KOENIG PESSOA                    | -
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=2B9P
#     ✔ OK — 5 campos | Bruto: 7.606,60 | Líquido: 5.795,37
#   [13/20] ADRIANO LUIZ DE CAMPOS                   | Servidor à disposiçã
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=byrP
#     ✔ OK — 8 campos | Bruto: 7.908,33 | Líquido: 4.596,73
#   [14/20] ADRIANO MARQUES                          | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=x660
#     ⚠ Tabela não encontrada para: ADRIANO MARQUES
#   [15/20] ADRIANO PIEKAS                           | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=3DYV
#     ✔ OK — 8 campos | Bruto: 28.980,37 | Líquido: 19.522,30
#   [16/20] ADRIANO RIBEIRO CARGNIN                  | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=QgRV
#     ✔ OK — 3 campos | Bruto: - | Líquido: -
#   [17/20] ADRIANO ROTTA                            | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=9apE
#     ✔ OK — 6 campos | Bruto: 14.698,75 | Líquido: 10.848,98
#   [18/20] ADRIANO SOUSA                            | Servidor à disposiçã
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=d8ge
#     ✔ OK — 5 campos | Bruto: 6.532,76 | Líquido: 5.920,79
#   [19/20] ADRIANO TEIXEIRA                         | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=gkW7
#     ✔ OK — 7 campos | Bruto: 3.740,40 | Líquido: 3.183,53
#   [20/20] ADROALDO MIRA                            | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=qV9
#     ✔ OK — 8 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   ✔ Página 3 concluída — total acumulado: 60 servidores
#
# [Pág   4/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] AFONSO PRATES DA SILVA JUNIOR            | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=bWP
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 27.545,14
#   [ 2/20] AFRANIO LUIZ MELERE                      | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=DqGN
#     ✔ OK — 5 campos | Bruto: 1.783,25 | Líquido: 1.647,08
#   [ 3/20] AGNALDO ONOFRE                           | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Wn17
#     ✔ OK — 6 campos | Bruto: 2.550,99 | Líquido: 2.345,73
#   [ 4/20] AGNES MARIA CARDOSO                      | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=8OK1
#     ✔ OK — 7 campos | Bruto: 1.666,96 | Líquido: 1.491,25
#   [ 5/20] AGOSTINHO LUIZ SCHIOCHETTI               | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Zzeb
#     ✔ OK — 5 campos | Bruto: 3.294,38 | Líquido: 3.010,47
#   [ 6/20] AIDA CUNHA DE OLIVEIRA                   | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=d28m
#     ✔ OK — 8 campos | Bruto: 35.051,74 | Líquido: 23.780,69
#   [ 7/20] AILSON JOAO VIEIRA                       | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=OZXQ
#     ⚠ Tabela não encontrada para: AILSON JOAO VIEIRA
#   [ 8/20] AILTON BONIFACIO BARBOSA                 | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=P6xd
#     ⚠ Tabela não encontrada para: AILTON BONIFACIO BARBOSA
#   [ 9/20] ALAIR NAZARETE PACHECO                   | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=70e
#     ✔ OK — 7 campos | Bruto: 22.541,34 | Líquido: 20.572,14
#   [10/20] ALAN ROBSON ARMILIATO                    | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=yboV
#     ✔ OK — 7 campos | Bruto: 20.110,04 | Líquido: 13.605,78
#   [11/20] ALBA LUCIA FONTES PIAZZA                 | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=QbqZ
#     ✔ OK — 6 campos | Bruto: 7.201,41 | Líquido: 5.562,52
#   [12/20] ALBERTINA BARRETO DE MELO                | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=6bo
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 28.016,59
#   [13/20] ALBERTINA PRATES                         | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=qoD
#     ✔ OK — 7 campos | Bruto: 24.800,92 | Líquido: 22.515,38
#   [14/20] ALBERTO CECHETTO BECK                    | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=opXQ
#     ✔ OK — 12 campos | Bruto: 41.845,49 | Líquido: 21.145,20
#   [15/20] ALBERTO JOSE SILVEIRA DE SA              | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ppq
#     ✔ OK — 11 campos | Bruto: 41.845,49 | Líquido: 29.614,01
#   [16/20] ALBERTO JUNIOR CORDEIRO DOS SANTOS       | Servidor à disposiçã
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ovpB
#     ✔ OK — 5 campos | Bruto: 6.000,00 | Líquido: 5.605,46
#   [17/20] ALBERTO MAGNO PALADINI                   | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=2Wx
#     ✔ OK — 14 campos | Bruto: 41.845,49 | Líquido: 20.709,12
#   [18/20] ALBERTO NEVES                            | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Yk3
#     ✔ OK — 7 campos | Bruto: 34.265,71 | Líquido: 30.655,10
#   [19/20] ALBERTO SABINO DE SOUZA JUNIOR           | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ybjA
#     ✔ OK — 5 campos | Bruto: 13.306,38 | Líquido: 9.839,51
#   [20/20] ALBINO GIUSTI                            | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=92DN
#     ✔ OK — 6 campos | Bruto: 4.194,23 | Líquido: 3.802,34
#   ✔ Página 4 concluída — total acumulado: 80 servidores
#
# [Pág   5/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] ALBINO TEIXEIRA                          | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Zoz
#     ✔ OK — 7 campos | Bruto: 16.766,81 | Líquido: 15.606,04
#   [ 2/20] ALCIDIO REIS PERA                        | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=1rzG
#     ✔ OK — 6 campos | Bruto: 9.969,61 | Líquido: 7.420,35
#   [ 3/20] ALCILEA MEDEIROS CARDOSO                 | Comissionado / Dispo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=qDvj
#     ✔ OK — 5 campos | Bruto: 6.202,07 | Líquido: 5.725,07
#   [ 4/20] ALCIONI TEREZINHA GRABOWSKI CALIKOSKI    | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=nxmP
#     ✔ OK — 6 campos | Bruto: 1.621,33 | Líquido: 1.370,04
#   [ 5/20] ALDA BORTOLOTTO PREIS                    | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=W6E
#     ✔ OK — 7 campos | Bruto: 9.121,22 | Líquido: 7.613,01
#   [ 6/20] ALDA SUZI REBELATO                       | Servidor à disposiçã
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=78Kg
#     ✔ OK — 7 campos | Bruto: 5.430,07 | Líquido: 4.239,76
#   [ 7/20] ALDENIR PINTO CAETANO                    | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ae2d
#     ✔ OK — 5 campos | Bruto: 4.144,76 | Líquido: 3.758,80
#   [ 8/20] ALDIR JOSE GOMES DA SILVA                | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Ko0
#     ✔ OK — 8 campos | Bruto: 41.845,49 | Líquido: 36.667,95
#   [ 9/20] ALDO DA SILVA GRANGEIRO                  | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=mpN
#     ✔ OK — 8 campos | Bruto: 39.519,88 | Líquido: 29.826,96
#   [10/20] ALDO LUIZ GARCIA                         | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=KvK
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 28.120,87
#   [11/20] ALDO MARQUES PERES FILHO                 | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=n0vP
#     ✔ OK — 8 campos | Bruto: 15.306,68 | Líquido: 10.454,08
#   [12/20] ALDORI MANOEL DE SOUZA                   | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=86wb
#     ✔ OK — 6 campos | Bruto: 10.337,06 | Líquido: 8.324,70
#   [13/20] ALEIDA CARDOSO CORREA                    | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=gXa8
#     ✔ OK — 6 campos | Bruto: 2.709,37 | Líquido: 2.387,29
#   [14/20] ALESIO DOS PASSOS SANTOS                 | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=RKY
#     ✔ OK — 5 campos | Bruto: 3.303,92 | Líquido: 2.885,69
#   [15/20] ALESSANDRO COLARES COELHO                | Servidor à disposiçã
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=pnGL
#     ✔ OK — 4 campos | Bruto: 4.950,94 | Líquido: 4.950,94
#   [16/20] ALESSANDRO MENDES MOTA                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=bjGD
#     ✔ OK — 7 campos | Bruto: 13.374,35 | Líquido: 9.113,08
#   [17/20] ALESSANDRO THOMAZONI                     | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=NGNk
#     ✔ OK — 5 campos | Bruto: 3.188,48 | Líquido: 2.917,28
#   [18/20] ALEX ANDRE OSTERKAMP                     | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=kbDo
#     ✔ OK — 7 campos | Bruto: 23.254,47 | Líquido: 15.917,44
#   [19/20] ALEX DAL PIVA                            | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=kpVz
#     ✔ OK — 6 campos | Bruto: 9.710,74 | Líquido: 7.232,67
#   [20/20] ALEX PEREIRA                             | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Lwrb
#     ✔ OK — 5 campos | Bruto: 4.144,76 | Líquido: 3.758,80
#   ✔ Página 5 concluída — total acumulado: 100 servidores
#
# [Pág   6/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] ALEX SANDRO DE JESUS                     | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=wd9p
#     ✔ OK — 7 campos | Bruto: 34.997,39 | Líquido: 25.565,49
#   [ 2/20] ALEXANDER BRASIL ALVES PEREIRA           | Deputado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=n098
#     ✔ OK — 6 campos | Bruto: 34.774,64 | Líquido: 23.387,07
#   [ 3/20] ALEXANDRA MARTINS MARQUES                | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=WpOV
#     ✔ OK — 5 campos | Bruto: 2.709,37 | Líquido: 2.489,85
#   [ 4/20] ALEXANDRE ALDO CIPRIANI                  | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=6r6
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   [ 5/20] ALEXANDRE CARLOS SUTIL                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Ywp8
#     ⚠ Tabela não encontrada para: ALEXANDRE CARLOS SUTIL
#   [ 6/20] ALEXANDRE DORTA CANELLA                  | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=WAYd
#     ✔ OK — 9 campos | Bruto: 40.432,44 | Líquido: 27.160,83
#   [ 7/20] ALEXANDRE FARIAS                         | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=w278
#     ✔ OK — 6 campos | Bruto: 2.622,87 | Líquido: 1.536,85
#   [ 8/20] ALEXANDRE FELIPE CORDEIRO                | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=2BpQ
#     ✔ OK — 6 campos | Bruto: 6.051,58 | Líquido: 5.120,45
#   [ 9/20] ALEXANDRE HERMANI DA SILVA               | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ELYZ
#     ✔ OK — 4 campos | Bruto: 9.160,00 | Líquido: 7.716,71
#   [10/20] ALEXANDRE JOAO DE SOUZA                  | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=6O09
#     ✔ OK — 6 campos | Bruto: 9.161,08 | Líquido: 6.834,17
#   [11/20] ALEXANDRE JOSE BACK                      | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=9bW0
#     ✔ OK — 11 campos | Bruto: 41.845,49 | Líquido: 21.458,02
#   [12/20] ALEXANDRE LENCINA FAGUNDES               | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=bk8D
#     ✔ OK — 8 campos | Bruto: 32.107,70 | Líquido: 19.401,53
#   [13/20] ALEXANDRE LOPES DOS SANTOS               | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=VwEE
#     ✔ OK — 6 campos | Bruto: 5.051,41 | Líquido: 4.524,32
#   [14/20] ALEXANDRE LUIS SOARES                    | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=MGa
#     ✔ OK — 15 campos | Bruto: 41.845,49 | Líquido: 19.534,16
#   [15/20] ALEXANDRE MELO                           | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=AGwQ
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 27.493,00
#   [16/20] ALEXANDRE PANTALEAO ATHANASIO            | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ORn
#     ✔ OK — 9 campos | Bruto: 29.377,68 | Líquido: 26.451,39
#   [17/20] ALEXANDRE PEREIRA CAMINHA                | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=zdo0
#     ✔ OK — 6 campos | Bruto: 5.051,41 | Líquido: 4.524,32
#   [18/20] ALEXANDRE REZENDE PEREIRA                | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=B1La
#     ✔ OK — 6 campos | Bruto: 4.660,00 | Líquido: 4.206,10
#   [19/20] ALEXANDRE RODRIGUES BADOTTI              | Servidor à disposiçã
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=8O1K
#     ✔ OK — 7 campos | Bruto: 4.232,26 | Líquido: 2.926,31
#   [20/20] ALEXANDRE SALVADOR                       | Servidor à disposiçã
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=WpZP
#     ✔ OK — 5 campos | Bruto: 5.593,54 | Líquido: 5.338,23
#   ✔ Página 6 concluída — total acumulado: 120 servidores
#
# [Pág   7/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] ALEXANDRE SCHAEFER                       | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ZzYb
#     ✔ OK — 7 campos | Bruto: 19.261,77 | Líquido: 13.491,93
#   [ 2/20] ALEXANDRE SOUZA DE LUCA                  | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=EoQp
#     ✔ OK — 4 campos | Bruto: 16.030,00 | Líquido: 12.697,46
#   [ 3/20] ALEXANDRO EDUARDO FERNANDES              | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=6G8y
#     ✔ OK — 6 campos | Bruto: 7.576,49 | Líquido: 5.251,11
#   [ 4/20] ALEXSANDRO GROSSL DE OLIVEIRA            | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=odnB
#     ✔ OK — 5 campos | Bruto: 2.987,09 | Líquido: 2.740,05
#   [ 5/20] ALEXSANDRO KOHL                          | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=dX6B
#     ✔ OK — 6 campos | Bruto: 5.714,70 | Líquido: 4.835,05
#   [ 6/20] ALFREDO REIS FERNANDES                   | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Wnxb
#     ⚠ Tabela não encontrada para: ALFREDO REIS FERNANDES
#   [ 7/20] ALINE CONSTANTINO BONFANTE DA ROSA       | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=v12z
#     ✔ OK — 6 campos | Bruto: 5.051,41 | Líquido: 4.524,32
#   [ 8/20] ALINE COSTA UEKER                        | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=9y30
#     ✔ OK — 5 campos | Bruto: 3.634,37 | Líquido: 3.309,66
#   [ 9/20] ALINE COVOLO RAVARA                      | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=P0Rg
#     ✔ OK — 11 campos | Bruto: 29.657,03 | Líquido: 19.680,98
#   [10/20] ALIPIA VIEIRA MOREIRA                    | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=6Bm
#     ✔ OK — 8 campos | Bruto: 25.977,01 | Líquido: 18.122,59
#   [11/20] ALIPIO INACIO ALVES                      | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=e7zW
#     ✔ OK — 8 campos | Bruto: 5.883,14 | Líquido: 4.717,05
#   [12/20] ALIRIO PEREIRA                           | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ZpAA
#     ⚠ Tabela não encontrada para: ALIRIO PEREIRA
#   [13/20] ALISSON DE SOUZA FRANCISCO               | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=3Vjr
#     ✔ OK — 9 campos | Bruto: 28.164,42 | Líquido: 17.265,59
#   [14/20] ALJIHAN KRUGER DE CARVALHO               | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=n0BD
#     ✔ OK — 10 campos | Bruto: 9.281,05 | Líquido: 6.781,37
#   [15/20] ALLAN DE SOUZA                           | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=gEGE
#     ✔ OK — 11 campos | Bruto: 36.251,95 | Líquido: 21.154,63
#   [16/20] ALLAN FRANCISCO JUNKES                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=dXww
#     ✔ OK — 6 campos | Bruto: 5.051,41 | Líquido: 4.524,32
#   [17/20] ALLAN MUNHOZ MADEIRA                     | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Rn8y
#     ✔ OK — 6 campos | Bruto: 8.747,59 | Líquido: 6.690,80
#   [18/20] ALMERINDA LEMOS THOME                    | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=pnjz
#     ✔ OK — 12 campos | Bruto: 41.845,49 | Líquido: 21.145,20
#   [19/20] ALMIR CIRICO                             | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=dnqw
#     ✔ OK — 7 campos | Bruto: 7.489,63 | Líquido: 5.722,43
#   [20/20] ALMIR DE SOUZA                           | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=e6nQ
#     ⚠ Tabela não encontrada para: ALMIR DE SOUZA
#   ✔ Página 7 concluída — total acumulado: 140 servidores
#
# [Pág   8/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] ALMIR VIEIRA STADLER                     | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=NR9
#     ✔ OK — 8 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   [ 2/20] ALOYSIO MACHADO FILHO                    | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=QbK2
#     ✔ OK — 9 campos | Bruto: 25.802,27 | Líquido: 18.899,03
#   [ 3/20] ALTAIR SILVA                             | Deputado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=MypL
#     ✔ OK — 6 campos | Bruto: 34.774,64 | Líquido: 23.387,07
#   [ 4/20] ALTAIR SANTOS DE AGUIAR                  | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=86o
#     ✔ OK — 8 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   [ 5/20] ALTAMIRO OSMAR KOERICH                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=2Vk
#     ✔ OK — 8 campos | Bruto: 34.034,16 | Líquido: 22.893,17
#   [ 6/20] ALTEMIR BEZ                              | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=gREg
#     ✔ OK — 3 campos | Bruto: - | Líquido: -
#   [ 7/20] ALVARO BERNARDES                         | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=mRme
#     ⚠ Tabela não encontrada para: ALVARO BERNARDES
#   [ 8/20] ALVARO PACHECO DE SOUZA                  | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Eve
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 27.597,27
#   [ 9/20] ALVARO SELVA GENTIL FILHO                | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ZOL
#     ✔ OK — 8 campos | Bruto: 32.122,39 | Líquido: 28.306,08
#   [10/20] AMADEU TERRES                            | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=B30
#     ✔ OK — 8 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   [11/20] AMADIR MANOEL DE MATOS                   | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=1dn
#     ✔ OK — 6 campos | Bruto: 13.330,92 | Líquido: 12.651,18
#   [12/20] AMANDA BORTOLUZZI MAIA JAROZINSKI        | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=pdpv
#     ✔ OK — 6 campos | Bruto: 2.026,27 | Líquido: 1.622,31
#   [13/20] AMANDA ISABELA NORCIO SCAPINI            | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=XnM3
#     ✔ OK — 5 campos | Bruto: 12.270,05 | Líquido: 9.088,17
#   [14/20] AMANDA WUEDJA GOMES DA SILVA             | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Oz1k
#     ✔ OK — 5 campos | Bruto: 12.270,05 | Líquido: 9.088,17
#   [15/20] AMANDHA CUNHA DA COSTA                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=aNp9
#     ✔ OK — 8 campos | Bruto: 8.940,25 | Líquido: 6.568,37
#   [16/20] AMARO RAMOS ORLANDI                      | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=gRP6
#     ✔ OK — 7 campos | Bruto: 41.173,79 | Líquido: 36.596,04
#   [17/20] AMAURI RAMOS                             | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=eopz
#     ⚠ Tabela não encontrada para: AMAURI RAMOS
#   [18/20] AMERICO CIPRIANO                         | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Ayva
#     ✔ OK — 7 campos | Bruto: 7.834,79 | Líquido: 5.937,64
#   [19/20] AMI NADABE OZELAME                       | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=K7ao
#     ✔ OK — 9 campos | Bruto: 24.223,42 | Líquido: 16.401,55
#   [20/20] AMILTO DA SILVA BENTO                    | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=xg2w
#     ✔ OK — 4 campos | Bruto: 16.030,00 | Líquido: 12.697,46
#   ✔ Página 8 concluída — total acumulado: 160 servidores
#
# [Pág   9/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] AMILTON DE ARAUJO SOARES                 | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=eLN
#     ✔ OK — 7 campos | Bruto: 32.826,79 | Líquido: 29.417,62
#   [ 2/20] AMILTON FERMINO DE SOUZA                 | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ZpeD
#     ⚠ Tabela não encontrada para: AMILTON FERMINO DE SOUZA
#   [ 3/20] AMILTON GONCALVES                        | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=eQZ
#     ✔ OK — 11 campos | Bruto: 41.845,49 | Líquido: 27.493,00
#   [ 4/20] ANA BERNARDETE MACHADO                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=GPO7
#     ✔ OK — 7 campos | Bruto: 25.106,51 | Líquido: 18.394,60
#   [ 5/20] ANA CAROLINA GABRIEL DE FARIAS           | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=mgZN
#     ⚠ Tabela não encontrada para: ANA CAROLINA GABRIEL DE FARIAS
#   [ 6/20] ANA CAMPAGNOLO                           | Deputado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=d8YL
#     ✔ OK — 6 campos | Bruto: 34.774,64 | Líquido: 23.387,07
#   [ 7/20] ANA CLAUDIA TORRET ROCHA                 | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=npb7
#     ✔ OK — 10 campos | Bruto: 16.406,26 | Líquido: 10.810,67
#   [ 8/20] ANA FLAVIA MARTINS DA SILVA              | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=3jqq
#     ✔ OK — 10 campos | Bruto: 33.683,95 | Líquido: 22.259,15
#   [ 9/20] ANA JULIA BIESDORF THIESEN               | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=vKaN
#     ✔ OK — 11 campos | Bruto: 24.821,44 | Líquido: 13.881,38
#   [10/20] ANA LUCIA COELHO MIGNONI BOTELHO         | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=e18
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 27.493,00
#   [11/20] ANA MARIA ALANO                          | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=GoGO
#     ✔ OK — 9 campos | Bruto: 41.845,49 | Líquido: 27.284,74
#   [12/20] ANA MARIA ALVES                          | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=mvA
#     ✔ OK — 8 campos | Bruto: 21.914,46 | Líquido: 15.589,59
#   [13/20] ANA MARIA BAGGIO DA SILVA                | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=KwqK
#     ✔ OK — 8 campos | Bruto: 40.464,21 | Líquido: 27.207,50
#   [14/20] ANA MARIA DA SILVA TEIXEIRA              | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=n0X
#     ✔ OK — 5 campos | Bruto: 6.570,91 | Líquido: 6.331,81
#   [15/20] ANA MARIA DE QUEIROZ GARCIA              | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=VQLW
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 28.016,59
#   [16/20] ANA MARIA FADEL                          | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=jV6r
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 28.016,59
#   [17/20] ANA MARIA GARIBOTTI                      | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=xde
#     ✔ OK — 9 campos | Bruto: 41.536,95 | Líquido: 36.908,36
#   [18/20] ANA MARIA MAIA RAMOS                     | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=KYD
#     ✔ OK — 11 campos | Bruto: 41.845,49 | Líquido: 28.016,59
#   [19/20] ANA MARIA PEIXOTO VILAR BERGONSE         | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=d8Qp
#     ✔ OK — 6 campos | Bruto: 21.245,59 | Líquido: 15.595,44
#   [20/20] ANA MARIS DE LIZ                         | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=37Gr
#     ✔ OK — 8 campos | Bruto: 3.503,03 | Líquido: 2.642,97
#   ✔ Página 9 concluída — total acumulado: 180 servidores
#
# [Pág  10/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] PAULINHA                                 | Deputado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=rZeA
#     ✔ OK — 5 campos | Bruto: 34.774,64 | Líquido: 25.404,00
#   [ 2/20] ANA PAULA DE SOUZA                       | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=bjNn
#     ✔ OK — 10 campos | Bruto: 37.887,08 | Líquido: 20.490,99
#   [ 3/20] ANA PAULA FURLAN VIEIRA                  | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ybWN
#     ✔ OK — 6 campos | Bruto: 12.270,05 | Líquido: 7.902,01
#   [ 4/20] ANA PAULA LINO                           | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=qdE8
#     ✔ OK — 6 campos | Bruto: 3.403,92 | Líquido: 2.967,02
#   [ 5/20] ANA PAULA REICHERT                       | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=kxEO
#     ✔ OK — 7 campos | Bruto: 4.127,94 | Líquido: 3.555,89
#   [ 6/20] ANA PAULA REITER                         | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=bkKn
#     ✔ OK — 8 campos | Bruto: 5.051,41 | Líquido: 4.120,21
#   [ 7/20] ANA PAULA TAVARES                        | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=v1z0
#     ✔ OK — 5 campos | Bruto: 2.709,37 | Líquido: 2.489,85
#   [ 8/20] ANA PAULA TAVARES FAGUNDES               | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=QRV1
#     ✔ OK — 9 campos | Bruto: 26.929,14 | Líquido: 18.935,07
#   [ 9/20] ANA RITA MORICONI                        | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=D3Z9
#     ✔ OK — 12 campos | Bruto: 41.845,49 | Líquido: 19.690,57
#   [10/20] ANA RUBENITA SILVEIRA DE ALMEIDA         | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ZzwL
#     ✔ OK — 5 campos | Bruto: 1.621,33 | Líquido: 1.499,74
#   [11/20] ANA TERRA DEPIZZOLATTI GONCALVES         | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=2xGE
#     ✔ OK — 12 campos | Bruto: 26.211,67 | Líquido: 14.375,86
#   [12/20] ANA VITORIA GONCALVES DOS SANTOS         | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Aq3Q
#     ✔ OK — 5 campos | Bruto: 8.124,76 | Líquido: 6.118,44
#   [13/20] ANDERSON AILTON BARBOSA                  | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=NLEk
#     ✔ OK — 13 campos | Bruto: 33.306,30 | Líquido: 17.320,11
#   [14/20] ANDERSON CARLOS DE MIRANDA               | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=WpDM
#     ✔ OK — 5 campos | Bruto: 3.755,57 | Líquido: 3.416,32
#   [15/20] ANDERSON CARLOS NASCIMENTO               | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=AqKy
#     ✔ OK — 5 campos | Bruto: 2.160,64 | Líquido: 1.990,51
#   [16/20] ANDERSON GOMES DA SILVA                  | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=xOvN
#     ✔ OK — 6 campos | Bruto: 10.337,06 | Líquido: 8.324,70
#   [17/20] ANDERSON MARCELO DZUMAN                  | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=AWVj
#     ⚠ Tabela não encontrada para: ANDERSON MARCELO DZUMAN
#   [18/20] ANDERSON RODRIGO SOUZA                   | Servidor à disposiçã
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=w2AB
#     ⚠ Tabela não encontrada para: ANDERSON RODRIGO SOUZA
#   [19/20] ANDERSON VILMAR MARTINS                  | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=NLkk
#     ✔ OK — 12 campos | Bruto: 30.004,38 | Líquido: 16.250,85
#   [20/20] ANDRE AUGUSTO MARCOLA                    | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=mwXk
#     ✔ OK — 5 campos | Bruto: 2.380,17 | Líquido: 2.190,28
#   ✔ Página 10 concluída — total acumulado: 200 servidores
#
# [Pág  11/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] ANDRE DE LIZ MEDEIROS                    | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=x20N
#     ✔ OK — 5 campos | Bruto: 2.160,64 | Líquido: 1.990,51
#   [ 2/20] ANDRE FELIPE HEE TERRA DO AMARAL         | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=x2dV
#     ✔ OK — 5 campos | Bruto: 4.728,46 | Líquido: 4.264,98
#   [ 3/20] ANDRE HESPANHOL DA SILVA                 | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=qPzQ
#     ✔ OK — 8 campos | Bruto: 35.960,62 | Líquido: 24.178,12
#   [ 4/20] ANDRE LUIZ BERNARDI                      | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=aB6L
#     ✔ OK — 9 campos | Bruto: 35.984,46 | Líquido: 24.194,02
#   [ 5/20] ANDRE LUIZ CARVALHO                      | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=6O29
#     ✔ OK — 5 campos | Bruto: 7.576,49 | Líquido: 5.776,59
#   [ 6/20] ANDRE LUIZ FARIAS                        | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=r000
#     ✔ OK — 6 campos | Bruto: 16.827,27 | Líquido: 12.392,15
#   [ 7/20] ANDRE LUIZ MARCOS                        | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=QNn2
#     ✔ OK — 5 campos | Bruto: 10.197,41 | Líquido: 7.585,51
#   [ 8/20] ANDRE LUIZ PACHECO FURTADO               | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=wDv
#     ✔ OK — 7 campos | Bruto: 32.255,02 | Líquido: 28.925,90
#   [ 9/20] ANDRE LUIZ SODRE DE OLIVEIRA             | Servidor à disposiçã
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=zovM
#     ✔ OK — 5 campos | Bruto: 11.781,06 | Líquido: 9.616,98
#   [10/20] ANDRE MESQUITA                           | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=k87v
#     ✔ OK — 5 campos | Bruto: 2.304,37 | Líquido: 2.121,30
#   [11/20] ANDRE RICARDO CALLAI                     | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=aNrd
#     ✔ OK — 9 campos | Bruto: 39.349,43 | Líquido: 27.579,59
#   [12/20] ANDRE RICARDO DE SOUZA                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=nK6b
#     ✔ OK — 7 campos | Bruto: 15.063,18 | Líquido: 10.239,53
#   [13/20] ANDRE VICENTE GOMES PEREIRA DE LIMA      | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=O8nq
#     ✔ OK — 5 campos | Bruto: 2.231,30 | Líquido: 2.054,81
#   [14/20] ANDRE WESSLER                            | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=QbBk
#     ✔ OK — 6 campos | Bruto: 12.457,00 | Líquido: 9.223,71
#   [15/20] ANDREA PEREIRA DA SILVA                  | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=qDGg
#     ✔ OK — 4 campos | Bruto: 10.337,06 | Líquido: 8.570,08
#   [16/20] ANDREA RIBEIRO BITTENCOURT               | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=B7e
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 27.493,00
#   [17/20] ANDREI JUNIOR ZAMONER                    | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=1BKn
#     ✔ OK — 7 campos | Bruto: 10.715,57 | Líquido: 7.677,95
#   [18/20] ANDREIA APARECIDA CAMARGO SILVA          | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=MMAw
#     ✔ OK — 5 campos | Bruto: 2.622,87 | Líquido: 2.411,14
#   [19/20] ANDREIA REGINA FILGUEIRAS                | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=9bpG
#     ✔ OK — 12 campos | Bruto: 31.091,70 | Líquido: 21.255,49
#   [20/20] ANDREY SAGAZ FORTE                       | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=wo6v
#     ✔ OK — 9 campos | Bruto: 33.070,93 | Líquido: 19.923,27
#   ✔ Página 11 concluída — total acumulado: 220 servidores
#
# [Pág  12/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] ANDREZA SOUZA DE CARVALHO                | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=0dPN
#     ✔ OK — 5 campos | Bruto: 2.622,87 | Líquido: 2.411,14
#   [ 2/20] ANDREZZA PERES                           | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=P6b1
#     ⚠ Tabela não encontrada para: ANDREZZA PERES
#   [ 3/20] ANE CAROLINE KLEINUBING SCHEFFER         | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=mkzv
#     ✔ OK — 12 campos | Bruto: 32.806,82 | Líquido: 16.928,83
#   [ 4/20] ANECI ALFREDO FINGER                     | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=BLm0
#     ✔ OK — 7 campos | Bruto: 6.409,23 | Líquido: 4.964,34
#   [ 5/20] ANGELA APARECIDA BEZ                     | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=0YK0
#     ✔ OK — 3 campos | Bruto: - | Líquido: -
#   [ 6/20] ANGELA MARIA BACK KOERICH                | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=OZnw
#     ✔ OK — 10 campos | Bruto: 32.611,26 | Líquido: 21.735,45
#   [ 7/20] ANGELA MARIA BITTENCOURT DA SILVA        | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Bw81
#     ✔ OK — 8 campos | Bruto: 8.612,24 | Líquido: 6.363,36
#   [ 8/20] ANGELA MARIA DE OLIVEIRA PEDERNEIRAS     | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=8kg
#     ✔ OK — 10 campos | Bruto: 34.065,22 | Líquido: 23.165,59
#   [ 9/20] ANGELINO SAVIO QUARTIERO                 | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=xvV
#     ✔ OK — 11 campos | Bruto: 41.845,49 | Líquido: 28.016,59
#   [10/20] ANGELO FERREIRA DA SILVA                 | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=voQ
#     ✔ OK — 9 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   [11/20] ANGELO JOAO MARGUTE                      | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=jVNe
#     ✔ OK — 7 campos | Bruto: 5.528,51 | Líquido: 4.750,92
#   [12/20] ANGELO RAMOS VIEIRA                      | Militar
# ...
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=B18B
#     ✔ OK — 9 campos | Bruto: 34.409,66 | Líquido: 17.872,20
#   [12/20] VITOR LUIZ SOARES BARTELEGA              | Comissionado / Dispo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=qdy0
#     ✔ OK — 7 campos | Bruto: 37.887,08 | Líquido: 27.782,72
#   [13/20] VITOR PAIVA DE OLIVEIRA                  | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=aedw
#     ✔ OK — 9 campos | Bruto: 25.600,96 | Líquido: 17.950,06
#   [14/20] VITOR ROQUE BLOTTA                       | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=k76X
#     ✔ OK — 5 campos | Bruto: 9.161,08 | Líquido: 6.834,17
#   [15/20] VITOR SCHMITT SILVEIRA                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=NLpm
#     ✔ OK — 7 campos | Bruto: 28.980,37 | Líquido: 21.203,15
#   [16/20] VIVIANA CORREA RAMOS                     | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ZzyD
#     ✔ OK — 5 campos | Bruto: 2.987,09 | Líquido: 2.740,05
#   [17/20] VIVIANE APARECIDA MARTINS CARDOSO BITTEN | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=QN9y
#     ✔ OK — 7 campos | Bruto: 10.197,41 | Líquido: 7.354,11
#   [18/20] VIVIANE CAMARGOS DE SOUSA                | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=P0Qd
#     ✔ OK — 11 campos | Bruto: 34.607,79 | Líquido: 23.476,76
#   [19/20] VIVIANE DE FATIMA THEISGES               | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=K3Xx
#     ✔ OK — 6 campos | Bruto: 9.679,24 | Líquido: 6.648,44
#   [20/20] VIVIANI BOOZ FERREIRA                    | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=mgYD
#     ✔ OK — 6 campos | Bruto: 5.396,89 | Líquido: 4.691,45
#   ✔ Página 134 concluída — total acumulado: 2680 servidores
#
# [Pág 135/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] VLADEMIR ALUISIO COSTA                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=oNYd
#     ✔ OK — 7 campos | Bruto: 7.088,40 | Líquido: 5.250,14
#   [ 2/20] VOLMAR GANDOLFI                          | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=A6eN
#     ✔ OK — 9 campos | Bruto: 2.960,77 | Líquido: 1.641,89
#   [ 3/20] VOLMAR ISATON                            | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=2xEx
#     ✔ OK — 7 campos | Bruto: 7.939,00 | Líquido: 6.052,43
#   [ 4/20] VOLNEI JOSE ESMERALDINO                  | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=d2n9
#     ✔ OK — 8 campos | Bruto: 19.060,79 | Líquido: 14.229,14
#   [ 5/20] VOLNEI MIRANDA                           | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=NGLm
#     ✔ OK — 6 campos | Bruto: 11.763,64 | Líquido: 8.721,02
#   [ 6/20] VOLNEI PINTO CARDOZO                     | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=P87O
#     ✔ OK — 5 campos | Bruto: 3.086,11 | Líquido: 2.827,19
#   [ 7/20] VOLNEI WEBER                             | Deputado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=oNne
#     ✔ OK — 5 campos | Bruto: 34.774,64 | Líquido: 25.404,00
#   [ 8/20] WAGNER ANTONIO ALVES                     | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=odNQ
#     ✔ OK — 6 campos | Bruto: 9.792,63 | Líquido: 7.292,04
#   [ 9/20] WAGNER COSTA NUNES                       | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=EexN
#     ✔ OK — 7 campos | Bruto: 3.517,20 | Líquido: 3.206,55
#   [10/20] WAGNER LEANDRO DE LIMA                   | Servidor à disposiçã
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=E8LR
#     ⚠ Tabela não encontrada para: WAGNER LEANDRO DE LIMA
#   [11/20] WAGNER OLIVEIRA MONTEIRO                 | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=mgv7
#     ✔ OK — 8 campos | Bruto: 28.192,62 | Líquido: 19.625,70
#   [12/20] WAGNER PEREIRA RAMOS                     | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=bkRn
#     ✔ OK — 7 campos | Bruto: 8.642,92 | Líquido: 3.577,53
#   [13/20] WAGNER ROBERTO BERNARDO                  | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=w2Y8
#     ✔ OK — 6 campos | Bruto: 2.752,42 | Líquido: 2.529,03
#   [14/20] WALBIA SALETE BITTENCOURT CORREA         | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=V0v
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 28.016,59
#   [15/20] WALDEMIRO ZIMMERMANN                     | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=EMYP
#     ⚠ Tabela não encontrada para: WALDEMIRO ZIMMERMANN
#   [16/20] WALDIR HENRIQUE WALTRICH                 | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Vb8D
#     ⚠ Tabela não encontrada para: WALDIR HENRIQUE WALTRICH
#   [17/20] WALMA CORREA SANTA RITTA                 | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=bYO
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 28.016,59
#   [18/20] WALMIR ADAO                              | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Xnk
#     ✔ OK — 7 campos | Bruto: 23.778,20 | Líquido: 21.635,84
#   [19/20] WALMIR DE OLIVEIRA MATOS                 | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=v93N
#     ✔ OK — 8 campos | Bruto: 27.773,07 | Líquido: 25.071,43
#   [20/20] WALMOR BACKES                            | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=0YZe
#     ⚠ Tabela não encontrada para: WALMOR BACKES
#   ✔ Página 135 concluída — total acumulado: 2700 servidores
#
# [Pág 136/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] WALTER DA LUZ                            | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=r03
#     ✔ OK — 9 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   [ 2/20] WALTER DIAS TEIXEIRA                     | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=7APq
#     ⚠ Tabela não encontrada para: WALTER DIAS TEIXEIRA
#   [ 3/20] WALTER FLORES STODIECK                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=w2K8
#     ✔ OK — 7 campos | Bruto: 5.720,31 | Líquido: 4.837,59
#   [ 4/20] WALTER MANOEL DA SILVEIRA                | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=XAby
#     ⚠ Tabela não encontrada para: WALTER MANOEL DA SILVEIRA
#   [ 5/20] WANDA MARIA NUNES                        | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Bp0
#     ✔ OK — 8 campos | Bruto: 24.656,67 | Líquido: 17.299,36
#   [ 6/20] WANDERLEIA MAY                           | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Pvk1
#     ✔ OK — 7 campos | Bruto: 9.161,08 | Líquido: 6.706,39
#   [ 7/20] WASHINGTON LUIS MIGNONI                  | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=2EQ
#     ✔ OK — 10 campos | Bruto: 41.197,01 | Líquido: 27.088,67
#   [ 8/20] WELLINGTON JOSE ZOMKOWSKI                | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=0YaV
#     ✔ OK — 2 campos | Bruto: - | Líquido: -
#   [ 9/20] WESLEY RODRIGUES DE SOUZA                | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Nozm
#     ⚠ Tabela não encontrada para: WESLEY RODRIGUES DE SOUZA
#   [10/20] WESLEY SANTOS DOS SANTOS                 | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=pEnp
#     ✔ OK — 5 campos | Bruto: 3.188,48 | Líquido: 2.917,28
#   [11/20] WESLLEY KNIES VALENCIO                   | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=wvn8
#     ⚠ Tabela não encontrada para: WESLLEY KNIES VALENCIO
#   [12/20] WILFREDO MEDEIROS DA SILVA               | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=DNp
#     ✔ OK — 7 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   [13/20] WILLIAM ANDRADE WRUBLESCHI               | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=v1GQ
#     ✔ OK — 5 campos | Bruto: 3.188,48 | Líquido: 2.917,28
#   [14/20] WILLIAM ANTONIO BROWN TEIXEIRA           | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=N3A
#     ✔ OK — 8 campos | Bruto: 19.781,15 | Líquido: 15.350,93
#   [15/20] WILLIAM MOREIRA PIMENTEL                 | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=7BEE
#     ✔ OK — 6 campos | Bruto: 19.261,77 | Líquido: 14.013,25
#   [16/20] WILLIAN ANDREI DE SOUZA DA ROSA          | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=xonw
#     ✔ OK — 6 campos | Bruto: 3.503,03 | Líquido: 3.194,08
#   [17/20] WILLIAN GIL MARTINS                      | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=MkK1
#     ✔ OK — 12 campos | Bruto: 29.433,59 | Líquido: 16.292,19
#   [18/20] WILLIAN GODOY FERREIRA DE SOUZA          | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ZzGq
#     ✔ OK — 5 campos | Bruto: 6.308,66 | Líquido: 5.124,75
#   [19/20] WILLIAN NELSON BARAN MOREIRA             | Servidor à disposiçã
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=VRrD
#     ✔ OK — 7 campos | Bruto: 11.013,98 | Líquido: 9.060,85
#   [20/20] WILMA RIBEIRO DA SILVA                   | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=xOV
#     ✔ OK — 8 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   ✔ Página 136 concluída — total acumulado: 2720 servidores
#
# [Pág 137/138] Buscando lista de servidores...
#   → 20 servidores encontrados nesta página
#   [ 1/20] WILMAR DA CONCEICAO                      | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=LeKe
#     ✔ OK — 7 campos | Bruto: 1.758,24 | Líquido: 1.571,58
#   [ 2/20] WILMAR LINHARES SOARES                   | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=6PQ
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 25.388,36
#   [ 3/20] WILSON LEMOS                             | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ov3
#     ✔ OK — 8 campos | Bruto: 41.845,49 | Líquido: 37.173,71
#   [ 4/20] WILSON PEREIRA MOTA                      | Comissionado / Dispo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=RREj
#     ✔ OK — 3 campos | Bruto: 1.851,38 | Líquido: 1.851,38
#   [ 5/20] WILSONEY GONCALVES                       | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=OzVn
#     ✔ OK — 9 campos | Bruto: 17.108,85 | Líquido: 11.589,97
#   [ 6/20] YARA LENTZ ALVES                         | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=9zM
#     ✔ OK — 9 campos | Bruto: 41.845,49 | Líquido: 28.016,59
#   [ 7/20] YASMIN LAPOLLI SILVEIRA DE SOUZA         | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=eA7Y
#     ✔ OK — 7 campos | Bruto: 23.254,47 | Líquido: 15.813,16
#   [ 8/20] YURI CRISTINE  KOUKETSU CANDIDO          | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=PvY9
#     ✔ OK — 6 campos | Bruto: 3.086,11 | Líquido: 2.703,75
#   [ 9/20] YURI LOURENCO DO AMARAL                  | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=p8p9
#     ✔ OK — 7 campos | Bruto: 4.709,21 | Líquido: 4.028,66
#   [10/20] ZACLIR SERGIO STOLARSKI                  | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=mRWw
#     ✔ OK — 6 campos | Bruto: 10.260,40 | Líquido: 7.631,17
#   [11/20] ZANILDE GRASIELA CRISTOFOLINI            | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=odaZ
#     ✔ OK — 7 campos | Bruto: 4.574,97 | Líquido: 3.690,74
#   [12/20] ZANY ESTAEL LEITE                        | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=X0x
#     ✔ OK — 10 campos | Bruto: 41.845,49 | Líquido: 28.016,59
#   [13/20] ZAVERSON SOARES REMOR                    | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Bq60
#     ✔ OK — 6 campos | Bruto: 9.160,00 | Líquido: 7.589,05
#   [14/20] ZELIA CARDOZO DOS SANTOS                 | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=qXVV
#     ✔ OK — 8 campos | Bruto: 8.368,50 | Líquido: 6.205,45
#   [15/20] ZELIA CECILIA DUARTE HOFFMANN            | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=D6N
#     ✔ OK — 8 campos | Bruto: 34.190,16 | Líquido: 23.243,49
#   [16/20] ZELIA TEREZINHA DE SOUZA                 | Efetivo
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=Gkd
#     ✔ OK — 13 campos | Bruto: 35.486,09 | Líquido: 16.979,80
#   [17/20] ZENAIDE MEYER                            | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=yN6
#     ✔ OK — 7 campos | Bruto: 22.973,48 | Líquido: 20.943,78
#   [18/20] ZENEIDE MARIA MACEDO MANSKE              | Comissionado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=gXAx
#     ✔ OK — 6 campos | Bruto: 3.188,48 | Líquido: 2.917,28
#   [19/20] ZENITE MARIA BARCELOS DOS SANTOS         | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=ybj
#     ✔ OK — 6 campos | Bruto: 25.503,82 | Líquido: 23.119,87
#   [20/20] ZILA FALCK BORTOLINI                     | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=B3Re
#     ✔ OK — 8 campos | Bruto: 41.830,94 | Líquido: 37.161,19
#   ✔ Página 137 concluída — total acumulado: 2740 servidores
#
# [Pág 138/138] Buscando lista de servidores...
#   → 5 servidores encontrados nesta página
#   [ 1/5] ZILA FALCK BORTOLINI                     | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=B3Re
#     ✔ OK — 8 campos | Bruto: 41.830,94 | Líquido: 37.161,19
#   [ 2/5] ZILA MACHADO FAUST                       | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=8GA
#     ✔ OK — 7 campos | Bruto: 31.536,72 | Líquido: 21.589,07
#   [ 3/5] ZULAMAR VERGILIO FRANCISCO               | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=DM7
#     ✔ OK — 8 campos | Bruto: 20.014,61 | Líquido: 14.771,71
#   [ 4/5] ZULMAR HERMOGENES SAIBRO                 | Aposentado
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=zKk
#     ✔ OK — 11 campos | Bruto: 41.845,49 | Líquido: 31.098,42
#   [ 5/5] ZULMAR NUNES                             | Militar
#          URL: https://transparencia.alesc.sc.gov.br/remuneracao.php?ID=6QbQ
#     ✔ OK — 4 campos | Bruto: 10.337,06 | Líquido: 8.570,08
#   ✔ Página 138 concluída — total acumulado: 2745 servidores
#
# ============================================================
# EXPORTANDO DADOS...
# ============================================================
# ✔ Arquivo 'relatorio_completo_alesc.csv' criado com sucesso!
#   Total de servidores exportados : 2745
#   Total de colunas               : 63
#   Erros em páginas               : 0
#   Holerites sem dados            : 187
# ============================================================
