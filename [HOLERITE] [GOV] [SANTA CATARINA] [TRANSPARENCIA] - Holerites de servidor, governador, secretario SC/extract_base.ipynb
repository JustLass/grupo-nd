# %% [markdown]
# # Imports e config

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC

from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.actions.wheel_input import ScrollOrigin
from dataclasses import dataclass, fields, asdict

import time

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(4)
wait = WebDriverWait(driver, 10)

# %% [markdown]
# # Config site

# %%
URL_BASE = 'https://www.transparencia.sc.gov.br/remuneracao-servidores'
driver.get(URL_BASE)

# %%
class Scraping():
    ''' Classe para alternar meses e páginas '''
    
    def __init__(self,ano):
        ''' Scraping do ano escolhido '''
        self.quantidade_paginas = 0
        self.ano = ano
    
    def quantidade_mes():
        '''
        Retorna a quantidade de meses
        '''
        mes = driver.find_element(By.CSS_SELECTOR, '#select-mes').get_property('children')
        return len(mes)
    
    def selecionar_mes(self, index):
        '''
        Seleciona o mês de acordo com o index e retorna qual mês foi selecionado
        '''
        mes = Select(driver.find_element(By.CSS_SELECTOR, '#select-mes'))
        mes.select_by_index(index)
        mes_atual = driver.find_element(By.CSS_SELECTOR, '#select-mes').get_property('children')[index].text
        return mes_atual
    
    def selecionar_ano(self):
        '''
        Seleciona o ano de acordo com a string específicada ex: "2025"
        '''
        ano = Select(driver.find_element(By.CSS_SELECTOR, '#select-ano'))
        print(f'Ano selecionado: {self.ano}')
        ano.select_by_visible_text(f'{self.ano}')
    
    def botao_buscar(self):
        ''' Clica em buscar servidores '''
        
        lupa = driver.find_element(By.CSS_SELECTOR, '.botao-buscar-servidor')
        ActionChains(driver).scroll_to_element(lupa).perform()
        lupa.click()

# %%
scrapy = Scraping(2025)
scrapy.selecionar_mes(1)
# Out:
# 'Fevereiro'

# %%
teste = Scraping(2025)

# %%
teste.botao_buscar()

# %% [markdown]
# # API SITE

# %% [markdown]
# O site contém API para os dados podemos coletar dados com eles

# %%
import requests
import pandas as pd
import time
import random
import os
import json
from datetime import datetime
from fake_useragent import UserAgent

# Configurações de Caminho
BASE_DIR = os.path.join("data", "base")
LOG_FILE = os.path.join(BASE_DIR, "scraping_log_2025.txt")
BASE_URL = "https://api-portal-transparencia.apps.sm.okd4.ciasc.sc.gov.br/api/remuneracao-servidores/analise-detalhada"
PAGES_PER_CHECKPOINT = 50

# Garante que a pasta existe
os.makedirs(BASE_DIR, exist_ok=True)

def get_status_progresso():
    if os.path.exists(LOG_FILE):
        with open(LOG_FILE, "r") as f:
            lines = f.readlines()
            if lines:
                last_line = lines[-1].strip()
                if "FIM:" in last_line:
                    partes = last_line.split("|")
                    mes = partes[0].split("Mes")[-1].strip()
                    pag = partes[1].split("Pagina")[-1].strip()
                    return mes, int(pag)
    return "01", 0

def save_to_csv(data_list, mes):
    filename = os.path.join(BASE_DIR, f"transparencia_sc_2025_{mes}.csv")
    df = pd.DataFrame(data_list)
    is_new = not os.path.exists(filename)
    df.to_csv(filename, mode='a', index=False, header=is_new, encoding='utf-8-sig')

def run_scraper():
    ua = UserAgent()
    session = requests.Session()
    
    ultimo_mes_log, ultima_pag_log = get_status_progresso()
    meses_2025 = [str(m).zfill(2) for m in range(1, 13)]
    meses_restantes = meses_2025[meses_2025.index(ultimo_mes_log):]

    print(f"{'='*70}")
    print(f"🚀 SCRAPER EM EXECUÇÃO - DESTINO: /data/base/")
    print(f"📍 Status: Iniciando em Mês {ultimo_mes_log} | Página {ultima_pag_log}")
    print(f"{'='*70}")

    try:
        for mes in meses_restantes:
            current_page = (ultima_pag_log + 1) if mes == ultimo_mes_log else 1
            last_page_limit = None
            temp_storage = []
            
            while True:
                headers = {
                    "User-Agent": ua.random,
                    "Referer": "https://www.transparencia.sc.gov.br/",
                    "Accept": "application/json"
                }
                
                params = {
                    "ano": 2025,
                    "mes": mes,
                    "page": current_page,
                    "filtro": json.dumps({"TIPOCONSULTA": "SERVIDORES", "nome": ""}),
                    "sort": json.dumps({"field": "ServidorNomeSort", "dir": "asc"})
                }

                try:
                    t_start = time.time()
                    response = session.get(BASE_URL, params=params, headers=headers, timeout=30)
                    response.raise_for_status()
                    json_data = response.json()
                    
                    if last_page_limit is None:
                        last_page_limit = json_data.get('last_page', 1)
                        print(f"\n[INFO] Mês {mes}/2025: {last_page_limit} páginas encontradas.")

                    batch = json_data.get('data', [])
                    
                    # INJEÇÃO DE DADOS (Mês e Ano)
                    for item in batch:
                        item['ref_mes'] = mes
                        item['ref_ano'] = 2025

                    temp_storage.extend(batch)
                    
                    # Dashboard de progresso no terminal
                    print(f"📡 [Mês {mes}] Pág: {current_page}/{last_page_limit} | "
                          f"Itens: {len(batch)} | Time: {time.time() - t_start:.2f}s", end='\r')

                    # Salva a cada X páginas ou na última do mês
                    if current_page % PAGES_PER_CHECKPOINT == 0 or current_page == last_page_limit:
                        save_to_csv(temp_storage, mes)
                        
                        with open(LOG_FILE, "a") as f:
                            f.write(f"FIM: Mes {mes} | Pagina {current_page}\n")
                        
                        print(f"\n💾 CHECKPOINT: Mês {mes}, Pág {current_page} salva em /data/base/")
                        temp_storage = []

                    if current_page >= last_page_limit:
                        print(f"\n✅ Mês {mes} finalizado!")
                        break
                    
                    current_page += 1
                    time.sleep(random.uniform(0, 0.5))

                except Exception as e:
                    print(f"\n🚨 Erro na Pág {current_page}: {str(e)[:100]}")
                    time.sleep(30)
                    continue
            
            ultima_pag_log = 0 

    except KeyboardInterrupt:
        print(f"\n\n🛑 Interrompido pelo usuário.")
    finally:
        if temp_storage:
            save_to_csv(temp_storage, mes)
        print(f"\n🏁 Fim da execução. Logs em: {LOG_FILE}")

if __name__ == "__main__":
    run_scraper()
# Out:
# ======================================================================
# 🚀 SCRAPER EM EXECUÇÃO - DESTINO: /data/base/
# 📍 Status: Iniciando em Mês 01 | Página 450
# ======================================================================
#
# [INFO] Mês 01/2025: 7158 páginas encontradas.
# 📡 [Mês 01] Pág: 500/7158 | Itens: 20 | Time: 0.30s
# 💾 CHECKPOINT: Mês 01, Pág 500 salva em /data/base/
# 📡 [Mês 01] Pág: 550/7158 | Itens: 20 | Time: 0.43s
# 💾 CHECKPOINT: Mês 01, Pág 550 salva em /data/base/
# 📡 [Mês 01] Pág: 600/7158 | Itens: 20 | Time: 0.32s
# 💾 CHECKPOINT: Mês 01, Pág 600 salva em /data/base/
# 📡 [Mês 01] Pág: 650/7158 | Itens: 20 | Time: 0.29s
# 💾 CHECKPOINT: Mês 01, Pág 650 salva em /data/base/
# 📡 [Mês 01] Pág: 700/7158 | Itens: 20 | Time: 0.28s
# 💾 CHECKPOINT: Mês 01, Pág 700 salva em /data/base/
# 📡 [Mês 01] Pág: 750/7158 | Itens: 20 | Time: 0.39s
# 💾 CHECKPOINT: Mês 01, Pág 750 salva em /data/base/
# 📡 [Mês 01] Pág: 791/7158 | Itens: 20 | Time: 0.24s
#
# 🛑 Interrompido pelo usuário.
#
# 🏁 Fim da execução. Logs em: data\base\scraping_log_2025.txt

# %%
import requests
import pandas as pd
import time
import random
import os
import json
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor
from fake_useragent import UserAgent

# Configurações de Caminho
BASE_DIR = os.path.join("data", "details")
os.makedirs(BASE_DIR, exist_ok=True)
BASE_URL = "https://api-portal-transparencia.apps.sm.okd4.ciasc.sc.gov.br/api/remuneracao-servidores/analise-detalhada"

def get_last_page_from_log(mes):
    """Lê o progresso específico de um mês."""
    log_path = os.path.join(BASE_DIR, f"log_mes_{mes}.txt")
    if os.path.exists(log_path):
        with open(log_path, "r") as f:
            line = f.read().strip()
            if line:
                return int(line)
    return 0

def salvar_checkpoint_mes(mes, pagina):
    """Registra a última página processada para evitar recomeço."""
    log_path = os.path.join(BASE_DIR, f"log_mes_{mes}.txt")
    with open(log_path, "w") as f:
        f.write(str(pagina))

def coletar_mes(mes):
    """Função que será executada em paralelo para cada mês."""
    ua = UserAgent()
    session = requests.Session()
    
    ultima_pag = get_last_page_from_log(mes)
    current_page = ultima_pag + 1
    last_page_limit = None
    temp_storage = []
    
    # Print inicial detalhado
    status = "RETOMANDO" if ultima_pag > 0 else "INICIANDO"
    print(f"📡 [{status}] Mês {mes}/2025 | Começando da Pág: {current_page}")

    while True:
        headers = {
            "User-Agent": ua.random,
            "Referer": "https://www.transparencia.sc.gov.br/",
            "Accept": "application/json"
        }
        
        params = {
            "ano": 2025,
            "mes": mes,
            "page": current_page,
            "filtro": json.dumps({"TIPOCONSULTA": "SERVIDORES", "nome": ""}),
            "sort": json.dumps({"field": "ServidorNomeSort", "dir": "asc"})
        }

        try:
            t_start = time.time()
            response = session.get(BASE_URL, params=params, headers=headers, timeout=30)
            response.raise_for_status()
            json_data = response.json()
            t_end = time.time()
            
            if last_page_limit is None:
                last_page_limit = json_data.get('last_page', 1)
                # Verifica se o mês já estava completo
                if current_page > last_page_limit:
                    print(f"✅ [Mês {mes}] Já estava 100% concluído anteriormente.")
                    break

            batch = json_data.get('data', [])
            
            # Injeção de metadados para sua análise como Data Analyst
            for item in batch:
                item['ref_mes'] = mes
                item['ref_ano'] = 2025
            
            temp_storage.extend(batch)

            # Print de andamento por página
            prog = (current_page / last_page_limit) * 100
            print(f"▶️ [Mês {mes}] Pág: {current_page}/{last_page_limit} ({prog:.1f}%) | Latência: {t_end - t_start:.2f}s")

            # Checkpoint a cada 50 páginas
            if current_page % 50 == 0 or current_page == last_page_limit:
                filename = os.path.join(BASE_DIR, f"transparencia_sc_2025_{mes}.csv")
                df = pd.DataFrame(temp_storage)
                df.to_csv(filename, mode='a', index=False, header=not os.path.exists(filename), encoding='utf-8-sig')
                
                salvar_checkpoint_mes(mes, current_page)
                
                print(f"💾 [Mês {mes}] CHECKPOINT: {len(temp_storage)} itens salvos. (Hora: {datetime.now().strftime('%H:%M:%S')})")
                temp_storage = [] 

            if current_page >= last_page_limit:
                print(f"🏆 [Mês {mes}] FINALIZADO COM SUCESSO!")
                break
            
            current_page += 1
            # Delay agressivo conforme seu teste bem-sucedido
            time.sleep(random.uniform(1, 2.5)) 

        except Exception as e:
            print(f"🚨 [Mês {mes}] ERRO na Pág {current_page}: {str(e)[:100]}")
            time.sleep(20) # Pausa para o servidor respirar
            continue

def run_multithreaded():
    meses = [str(m).zfill(2) for m in range(1, 13)]
    
    print(f"{'='*70}")
    print(f"🔥 INICIANDO EXTRAÇÃO PARALELA (4 THREADS) - AGRESSIVE MODE")
    print(f"📁 Destino: {BASE_DIR}")
    print(f"{'='*70}")
    
    # max_workers=4 é o ideal para o seu processador Intel equilibrar velocidade e estabilidade
    with ThreadPoolExecutor(max_workers=4) as executor:
        executor.map(coletar_mes, meses)

if __name__ == "__main__":
    start_total = time.time()
    try:
        run_multithreaded()
    except KeyboardInterrupt:
        print(f"\n🛑 Interrupção manual detectada pelo usuário.")
    finally:
        print(f"\n{'='*70}")
        print(f"✨ TUDO PRONTO! Tempo Total: {time.time() - start_total:.2f}s")
        print(f"{'='*70}")
# Out:
# ======================================================================
# 🔥 INICIANDO EXTRAÇÃO PARALELA (4 THREADS) - AGRESSIVE MODE
# 📁 Destino: data\details
# ======================================================================
# 📡 [RETOMANDO] Mês 04/2025 | Começando da Pág: 151
# 📡 [RETOMANDO] Mês 03/2025 | Começando da Pág: 151
# 📡 [RETOMANDO] Mês 02/2025 | Começando da Pág: 151
# 📡 [RETOMANDO] Mês 01/2025 | Começando da Pág: 151
# ▶️ [Mês 02] Pág: 151/7994 (1.9%) | Latência: 0.48s
# ▶️ [Mês 01] Pág: 151/7158 (2.1%) | Latência: 0.48s
# ▶️ [Mês 04] Pág: 151/9153 (1.6%) | Latência: 0.49s
# ▶️ [Mês 03] Pág: 151/8886 (1.7%) | Latência: 0.49s
# ▶️ [Mês 02] Pág: 152/7994 (1.9%) | Latência: 0.20s
# ▶️ [Mês 01] Pág: 152/7158 (2.1%) | Latência: 0.17s
# ▶️ [Mês 03] Pág: 152/8886 (1.7%) | Latência: 0.29s
# ▶️ [Mês 04] Pág: 152/9153 (1.7%) | Latência: 0.19s
# ▶️ [Mês 01] Pág: 153/7158 (2.1%) | Latência: 0.15s
# ▶️ [Mês 02] Pág: 153/7994 (1.9%) | Latência: 0.17s
# ▶️ [Mês 04] Pág: 153/9153 (1.7%) | Latência: 0.18s
# ▶️ [Mês 03] Pág: 153/8886 (1.7%) | Latência: 0.19s
# ▶️ [Mês 03] Pág: 154/8886 (1.7%) | Latência: 0.32s
# ▶️ [Mês 04] Pág: 154/9153 (1.7%) | Latência: 0.21s
# ▶️ [Mês 01] Pág: 154/7158 (2.2%) | Latência: 0.23s
# ▶️ [Mês 02] Pág: 154/7994 (1.9%) | Latência: 0.22s
# ▶️ [Mês 04] Pág: 155/9153 (1.7%) | Latência: 0.23s
# ▶️ [Mês 03] Pág: 155/8886 (1.7%) | Latência: 0.19s
# ▶️ [Mês 01] Pág: 155/7158 (2.2%) | Latência: 0.28s
# ▶️ [Mês 02] Pág: 155/7994 (1.9%) | Latência: 0.18s
# ▶️ [Mês 03] Pág: 156/8886 (1.8%) | Latência: 0.50s
# ▶️ [Mês 04] Pág: 156/9153 (1.7%) | Latência: 0.67s
# ▶️ [Mês 02] Pág: 156/7994 (2.0%) | Latência: 0.62s
# ▶️ [Mês 01] Pág: 156/7158 (2.2%) | Latência: 0.82s
# ▶️ [Mês 02] Pág: 157/7994 (2.0%) | Latência: 0.14s
# ▶️ [Mês 03] Pág: 157/8886 (1.8%) | Latência: 0.29s
# ▶️ [Mês 01] Pág: 157/7158 (2.2%) | Latência: 0.18s
# ▶️ [Mês 04] Pág: 157/9153 (1.7%) | Latência: 0.21s
# ▶️ [Mês 02] Pág: 158/7994 (2.0%) | Latência: 0.38s
# ▶️ [Mês 03] Pág: 158/8886 (1.8%) | Latência: 0.20s
# ▶️ [Mês 03] Pág: 159/8886 (1.8%) | Latência: 0.27s
# ▶️ [Mês 01] Pág: 158/7158 (2.2%) | Latência: 0.55s
# ▶️ [Mês 04] Pág: 158/9153 (1.7%) | Latência: 0.42s
# ▶️ [Mês 02] Pág: 159/7994 (2.0%) | Latência: 0.15s
# ▶️ [Mês 03] Pág: 160/8886 (1.8%) | Latência: 0.31s
# ▶️ [Mês 01] Pág: 159/7158 (2.2%) | Latência: 0.24s
# ▶️ [Mês 02] Pág: 160/7994 (2.0%) | Latência: 0.21s
# ▶️ [Mês 04] Pág: 159/9153 (1.7%) | Latência: 0.13s
# ▶️ [Mês 04] Pág: 160/9153 (1.7%) | Latência: 0.24s
# ▶️ [Mês 03] Pág: 161/8886 (1.8%) | Latência: 0.31s
# ▶️ [Mês 02] Pág: 161/7994 (2.0%) | Latência: 0.30s
# ▶️ [Mês 01] Pág: 160/7158 (2.2%) | Latência: 0.21s
# ▶️ [Mês 01] Pág: 161/7158 (2.2%) | Latência: 0.30s
# ▶️ [Mês 03] Pág: 162/8886 (1.8%) | Latência: 0.51s
# ▶️ [Mês 04] Pág: 161/9153 (1.8%) | Latência: 0.61s
# ▶️ [Mês 02] Pág: 162/7994 (2.0%) | Latência: 0.65s
# ▶️ [Mês 01] Pág: 162/7158 (2.3%) | Latência: 0.34s
# ▶️ [Mês 04] Pág: 162/9153 (1.8%) | Latência: 0.22s
# ▶️ [Mês 03] Pág: 163/8886 (1.8%) | Latência: 0.17s
# ▶️ [Mês 02] Pág: 163/7994 (2.0%) | Latência: 0.33s
# ▶️ [Mês 01] Pág: 163/7158 (2.3%) | Latência: 0.25s
# ▶️ [Mês 03] Pág: 164/8886 (1.8%) | Latência: 0.40s
# ▶️ [Mês 02] Pág: 164/7994 (2.1%) | Latência: 0.36s
# ▶️ [Mês 04] Pág: 163/9153 (1.8%) | Latência: 0.50s
# ▶️ [Mês 01] Pág: 164/7158 (2.3%) | Latência: 0.41s
# ▶️ [Mês 04] Pág: 164/9153 (1.8%) | Latência: 0.28s
# ▶️ [Mês 03] Pág: 165/8886 (1.9%) | Latência: 0.35s
# ▶️ [Mês 02] Pág: 165/7994 (2.1%) | Latência: 0.26s
# ▶️ [Mês 01] Pág: 165/7158 (2.3%) | Latência: 0.41s
# ▶️ [Mês 03] Pág: 166/8886 (1.9%) | Latência: 0.32s
# ▶️ [Mês 04] Pág: 165/9153 (1.8%) | Latência: 0.39s
# ▶️ [Mês 02] Pág: 166/7994 (2.1%) | Latência: 0.14s
# ▶️ [Mês 01] Pág: 166/7158 (2.3%) | Latência: 0.25s
# ▶️ [Mês 04] Pág: 166/9153 (1.8%) | Latência: 0.26s
# ▶️ [Mês 03] Pág: 167/8886 (1.9%) | Latência: 0.30s
# ▶️ [Mês 02] Pág: 167/7994 (2.1%) | Latência: 0.13s
# ▶️ [Mês 01] Pág: 167/7158 (2.3%) | Latência: 0.18s
# ▶️ [Mês 04] Pág: 167/9153 (1.8%) | Latência: 0.22s
# ▶️ [Mês 03] Pág: 168/8886 (1.9%) | Latência: 0.26s
# ▶️ [Mês 02] Pág: 168/7994 (2.1%) | Latência: 0.20s
# ▶️ [Mês 04] Pág: 168/9153 (1.8%) | Latência: 0.24s
# ▶️ [Mês 01] Pág: 168/7158 (2.3%) | Latência: 0.18s
# ▶️ [Mês 03] Pág: 169/8886 (1.9%) | Latência: 0.24s
# ▶️ [Mês 02] Pág: 169/7994 (2.1%) | Latência: 0.21s
# ▶️ [Mês 01] Pág: 169/7158 (2.4%) | Latência: 0.23s
# ▶️ [Mês 04] Pág: 169/9153 (1.8%) | Latência: 0.14s
# ▶️ [Mês 01] Pág: 170/7158 (2.4%) | Latência: 0.28s
# ▶️ [Mês 03] Pág: 170/8886 (1.9%) | Latência: 0.27s
# ▶️ [Mês 02] Pág: 170/7994 (2.1%) | Latência: 0.21s
# ▶️ [Mês 04] Pág: 170/9153 (1.9%) | Latência: 0.25s
# ▶️ [Mês 02] Pág: 171/7994 (2.1%) | Latência: 0.26s
# ▶️ [Mês 01] Pág: 171/7158 (2.4%) | Latência: 0.23s
# ▶️ [Mês 03] Pág: 171/8886 (1.9%) | Latência: 0.36s
# ▶️ [Mês 04] Pág: 171/9153 (1.9%) | Latência: 0.15s
# ▶️ [Mês 02] Pág: 172/7994 (2.2%) | Latência: 0.23s
# ▶️ [Mês 03] Pág: 172/8886 (1.9%) | Latência: 0.31s
# ▶️ [Mês 01] Pág: 172/7158 (2.4%) | Latência: 0.26s
# ▶️ [Mês 04] Pág: 172/9153 (1.9%) | Latência: 0.31s
# ▶️ [Mês 02] Pág: 173/7994 (2.2%) | Latência: 0.31s
# ▶️ [Mês 03] Pág: 173/8886 (1.9%) | Latência: 0.22s
# ▶️ [Mês 01] Pág: 173/7158 (2.4%) | Latência: 0.25s
# ▶️ [Mês 04] Pág: 173/9153 (1.9%) | Latência: 0.23s
# ▶️ [Mês 02] Pág: 174/7994 (2.2%) | Latência: 0.13s
# ▶️ [Mês 03] Pág: 174/8886 (2.0%) | Latência: 0.27s
# ▶️ [Mês 01] Pág: 174/7158 (2.4%) | Latência: 0.24s
# ▶️ [Mês 03] Pág: 175/8886 (2.0%) | Latência: 0.29s
# ▶️ [Mês 04] Pág: 174/9153 (1.9%) | Latência: 0.25s
# ▶️ [Mês 02] Pág: 175/7994 (2.2%) | Latência: 0.30s
# ▶️ [Mês 03] Pág: 176/8886 (2.0%) | Latência: 0.27s
# ▶️ [Mês 02] Pág: 176/7994 (2.2%) | Latência: 0.31s
# ▶️ [Mês 04] Pág: 175/9153 (1.9%) | Latência: 0.22s
# ▶️ [Mês 01] Pág: 175/7158 (2.4%) | Latência: 0.17s
# ▶️ [Mês 03] Pág: 177/8886 (2.0%) | Latência: 0.14s
# ▶️ [Mês 01] Pág: 176/7158 (2.5%) | Latência: 0.27s
# ▶️ [Mês 04] Pág: 176/9153 (1.9%) | Latência: 0.37s
# ▶️ [Mês 02] Pág: 177/7994 (2.2%) | Latência: 0.26s
# ▶️ [Mês 03] Pág: 178/8886 (2.0%) | Latência: 0.33s
# ▶️ [Mês 01] Pág: 177/7158 (2.5%) | Latência: 0.14s
# ▶️ [Mês 02] Pág: 178/7994 (2.2%) | Latência: 0.36s
# ▶️ [Mês 04] Pág: 177/9153 (1.9%) | Latência: 0.16s
# ▶️ [Mês 02] Pág: 179/7994 (2.2%) | Latência: 0.33s
# ▶️ [Mês 03] Pág: 179/8886 (2.0%) | Latência: 0.42s
# ▶️ [Mês 04] Pág: 178/9153 (1.9%) | Latência: 0.43s
# ▶️ [Mês 01] Pág: 178/7158 (2.5%) | Latência: 0.39s
# ▶️ [Mês 03] Pág: 180/8886 (2.0%) | Latência: 0.40s
# ▶️ [Mês 02] Pág: 180/7994 (2.3%) | Latência: 0.39s
# ▶️ [Mês 01] Pág: 179/7158 (2.5%) | Latência: 0.60s
# ▶️ [Mês 04] Pág: 179/9153 (2.0%) | Latência: 0.51s
# ▶️ [Mês 03] Pág: 181/8886 (2.0%) | Latência: 0.31s
# ▶️ [Mês 02] Pág: 181/7994 (2.3%) | Latência: 0.31s
# ▶️ [Mês 04] Pág: 180/9153 (2.0%) | Latência: 0.30s
# ▶️ [Mês 02] Pág: 182/7994 (2.3%) | Latência: 0.17s
# ▶️ [Mês 03] Pág: 182/8886 (2.0%) | Latência: 0.34s
# ▶️ [Mês 01] Pág: 180/7158 (2.5%) | Latência: 0.30s
# ▶️ [Mês 04] Pág: 181/9153 (2.0%) | Latência: 0.15s
# ▶️ [Mês 02] Pág: 183/7994 (2.3%) | Latência: 0.21s
# ▶️ [Mês 01] Pág: 181/7158 (2.5%) | Latência: 0.18s
# ▶️ [Mês 03] Pág: 183/8886 (2.1%) | Latência: 0.23s
# ▶️ [Mês 02] Pág: 184/7994 (2.3%) | Latência: 0.30s
# ▶️ [Mês 04] Pág: 182/9153 (2.0%) | Latência: 0.24s
# ▶️ [Mês 01] Pág: 182/7158 (2.5%) | Latência: 0.14s
# ▶️ [Mês 03] Pág: 184/8886 (2.1%) | Latência: 0.29s
# ▶️ [Mês 04] Pág: 183/9153 (2.0%) | Latência: 0.28s
# ▶️ [Mês 03] Pág: 185/8886 (2.1%) | Latência: 0.34s
# ▶️ [Mês 02] Pág: 185/7994 (2.3%) | Latência: 0.12s
# ▶️ [Mês 01] Pág: 183/7158 (2.6%) | Latência: 0.21s
# ▶️ [Mês 03] Pág: 186/8886 (2.1%) | Latência: 0.19s
# ▶️ [Mês 04] Pág: 184/9153 (2.0%) | Latência: 0.18s
# ▶️ [Mês 01] Pág: 184/7158 (2.6%) | Latência: 0.28s
# ▶️ [Mês 02] Pág: 186/7994 (2.3%) | Latência: 0.22s
# ▶️ [Mês 03] Pág: 187/8886 (2.1%) | Latência: 0.36s
# ▶️ [Mês 04] Pág: 185/9153 (2.0%) | Latência: 0.94s
# ▶️ [Mês 03] Pág: 188/8886 (2.1%) | Latência: 0.12s
# ▶️ [Mês 02] Pág: 187/7994 (2.3%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 185/7158 (2.6%) | Latência: 0.18s
# ▶️ [Mês 04] Pág: 186/9153 (2.0%) | Latência: 0.14s
# ▶️ [Mês 03] Pág: 189/8886 (2.1%) | Latência: 0.22s
# ▶️ [Mês 02] Pág: 188/7994 (2.4%) | Latência: 0.18s
# ▶️ [Mês 01] Pág: 186/7158 (2.6%) | Latência: 0.13s
# ▶️ [Mês 04] Pág: 187/9153 (2.0%) | Latência: 0.11s
# ▶️ [Mês 03] Pág: 190/8886 (2.1%) | Latência: 0.16s
# ▶️ [Mês 02] Pág: 189/7994 (2.4%) | Latência: 0.40s
# ▶️ [Mês 01] Pág: 187/7158 (2.6%) | Latência: 0.16s
# ▶️ [Mês 04] Pág: 188/9153 (2.1%) | Latência: 0.19s
# ▶️ [Mês 02] Pág: 190/7994 (2.4%) | Latência: 0.14s
# ▶️ [Mês 03] Pág: 191/8886 (2.1%) | Latência: 0.17s
# ▶️ [Mês 01] Pág: 188/7158 (2.6%) | Latência: 0.16s
# ▶️ [Mês 02] Pág: 191/7994 (2.4%) | Latência: 0.15s
# ▶️ [Mês 04] Pág: 189/9153 (2.1%) | Latência: 0.16s
# ▶️ [Mês 03] Pág: 192/8886 (2.2%) | Latência: 0.17s
# ▶️ [Mês 02] Pág: 192/7994 (2.4%) | Latência: 0.12s
# ▶️ [Mês 01] Pág: 189/7158 (2.6%) | Latência: 0.16s
# ▶️ [Mês 03] Pág: 193/8886 (2.2%) | Latência: 0.15s
# ▶️ [Mês 04] Pág: 190/9153 (2.1%) | Latência: 0.15s
# ▶️ [Mês 02] Pág: 193/7994 (2.4%) | Latência: 0.16s
# ▶️ [Mês 03] Pág: 194/8886 (2.2%) | Latência: 0.14s
# ▶️ [Mês 01] Pág: 190/7158 (2.7%) | Latência: 0.15s
# ▶️ [Mês 02] Pág: 194/7994 (2.4%) | Latência: 0.17s
# ▶️ [Mês 04] Pág: 191/9153 (2.1%) | Latência: 0.15s
# ▶️ [Mês 01] Pág: 191/7158 (2.7%) | Latência: 0.17s
# ▶️ [Mês 03] Pág: 195/8886 (2.2%) | Latência: 0.14s
# ▶️ [Mês 02] Pág: 195/7994 (2.4%) | Latência: 0.23s
# ▶️ [Mês 03] Pág: 196/8886 (2.2%) | Latência: 0.17s
# ▶️ [Mês 01] Pág: 192/7158 (2.7%) | Latência: 0.12s
# ▶️ [Mês 04] Pág: 192/9153 (2.1%) | Latência: 0.12s
# ▶️ [Mês 02] Pág: 196/7994 (2.5%) | Latência: 0.11s
# ▶️ [Mês 03] Pág: 197/8886 (2.2%) | Latência: 0.12s
# ▶️ [Mês 04] Pág: 193/9153 (2.1%) | Latência: 0.17s
# ▶️ [Mês 01] Pág: 193/7158 (2.7%) | Latência: 0.11s
# ▶️ [Mês 03] Pág: 198/8886 (2.2%) | Latência: 0.17s
# ▶️ [Mês 04] Pág: 194/9153 (2.1%) | Latência: 0.16s
# ▶️ [Mês 02] Pág: 197/7994 (2.5%) | Latência: 0.14s
# ▶️ [Mês 01] Pág: 194/7158 (2.7%) | Latência: 0.12s
# ▶️ [Mês 03] Pág: 199/8886 (2.2%) | Latência: 0.21s
# ▶️ [Mês 04] Pág: 195/9153 (2.1%) | Latência: 0.37s
# ▶️ [Mês 02] Pág: 198/7994 (2.5%) | Latência: 0.30s
# ▶️ [Mês 01] Pág: 195/7158 (2.7%) | Latência: 0.21s
# ▶️ [Mês 04] Pág: 196/9153 (2.1%) | Latência: 0.25s
# ▶️ [Mês 03] Pág: 200/8886 (2.3%) | Latência: 0.15s
# 💾 [Mês 03] CHECKPOINT: 1000 itens salvos. (Hora: 16:46:46)
# ▶️ [Mês 02] Pág: 199/7994 (2.5%) | Latência: 0.13s
# ▶️ [Mês 01] Pág: 196/7158 (2.7%) | Latência: 0.20s
# ▶️ [Mês 04] Pág: 197/9153 (2.2%) | Latência: 0.22s
# ▶️ [Mês 02] Pág: 200/7994 (2.5%) | Latência: 0.25s
# ▶️ [Mês 03] Pág: 201/8886 (2.3%) | Latência: 0.31s
# 💾 [Mês 02] CHECKPOINT: 1000 itens salvos. (Hora: 16:46:49)
# ▶️ [Mês 01] Pág: 197/7158 (2.8%) | Latência: 0.18s
# ▶️ [Mês 04] Pág: 198/9153 (2.2%) | Latência: 0.45s
# ▶️ [Mês 03] Pág: 202/8886 (2.3%) | Latência: 0.12s
# ▶️ [Mês 02] Pág: 201/7994 (2.5%) | Latência: 0.12s
# ▶️ [Mês 01] Pág: 198/7158 (2.8%) | Latência: 0.15s
# ▶️ [Mês 04] Pág: 199/9153 (2.2%) | Latência: 0.18s
# ▶️ [Mês 03] Pág: 203/8886 (2.3%) | Latência: 0.30s
# ▶️ [Mês 02] Pág: 202/7994 (2.5%) | Latência: 0.24s
# ▶️ [Mês 01] Pág: 199/7158 (2.8%) | Latência: 0.14s
# ▶️ [Mês 04] Pág: 200/9153 (2.2%) | Latência: 0.16s
# 💾 [Mês 04] CHECKPOINT: 1000 itens salvos. (Hora: 16:46:54)
# ▶️ [Mês 02] Pág: 203/7994 (2.5%) | Latência: 0.16s
# ▶️ [Mês 03] Pág: 204/8886 (2.3%) | Latência: 0.15s
# ▶️ [Mês 01] Pág: 200/7158 (2.8%) | Latência: 0.16s
# ▶️ [Mês 04] Pág: 201/9153 (2.2%) | Latência: 0.16s
# 💾 [Mês 01] CHECKPOINT: 1000 itens salvos. (Hora: 16:46:55)
# ▶️ [Mês 02] Pág: 204/7994 (2.6%) | Latência: 0.20s
# ▶️ [Mês 03] Pág: 205/8886 (2.3%) | Latência: 0.16s
# ▶️ [Mês 01] Pág: 201/7158 (2.8%) | Latência: 0.12s
# ▶️ [Mês 04] Pág: 202/9153 (2.2%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 205/7994 (2.6%) | Latência: 0.16s
# ▶️ [Mês 04] Pág: 203/9153 (2.2%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 206/8886 (2.3%) | Latência: 0.15s
# ▶️ [Mês 01] Pág: 202/7158 (2.8%) | Latência: 0.14s
# ▶️ [Mês 02] Pág: 206/7994 (2.6%) | Latência: 0.16s
# ▶️ [Mês 04] Pág: 204/9153 (2.2%) | Latência: 0.16s
# ▶️ [Mês 01] Pág: 203/7158 (2.8%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 207/8886 (2.3%) | Latência: 0.13s
# ▶️ [Mês 04] Pág: 205/9153 (2.2%) | Latência: 0.17s
# ▶️ [Mês 02] Pág: 207/7994 (2.6%) | Latência: 0.18s
# ▶️ [Mês 03] Pág: 208/8886 (2.3%) | Latência: 0.27s
# ▶️ [Mês 01] Pág: 204/7158 (2.8%) | Latência: 0.19s
# ▶️ [Mês 04] Pág: 206/9153 (2.3%) | Latência: 0.15s
# ▶️ [Mês 01] Pág: 205/7158 (2.9%) | Latência: 0.17s
# ▶️ [Mês 02] Pág: 208/7994 (2.6%) | Latência: 0.23s
# ▶️ [Mês 03] Pág: 209/8886 (2.4%) | Latência: 0.16s
# ▶️ [Mês 01] Pág: 206/7158 (2.9%) | Latência: 0.11s
# ▶️ [Mês 04] Pág: 207/9153 (2.3%) | Latência: 0.15s
# ▶️ [Mês 02] Pág: 209/7994 (2.6%) | Latência: 0.15s
# ▶️ [Mês 03] Pág: 210/8886 (2.4%) | Latência: 0.12s
# ▶️ [Mês 01] Pág: 207/7158 (2.9%) | Latência: 0.21s
# ▶️ [Mês 03] Pág: 211/8886 (2.4%) | Latência: 0.16s
# ▶️ [Mês 04] Pág: 208/9153 (2.3%) | Latência: 0.18s
# ▶️ [Mês 02] Pág: 210/7994 (2.6%) | Latência: 0.39s
# ▶️ [Mês 01] Pág: 208/7158 (2.9%) | Latência: 0.14s
# ▶️ [Mês 03] Pág: 212/8886 (2.4%) | Latência: 0.11s
# ▶️ [Mês 04] Pág: 209/9153 (2.3%) | Latência: 0.14s
# ▶️ [Mês 02] Pág: 211/7994 (2.6%) | Latência: 0.15s
# ▶️ [Mês 01] Pág: 209/7158 (2.9%) | Latência: 0.24s
# ▶️ [Mês 03] Pág: 213/8886 (2.4%) | Latência: 0.23s
# ▶️ [Mês 02] Pág: 212/7994 (2.7%) | Latência: 0.13s
# ▶️ [Mês 04] Pág: 210/9153 (2.3%) | Latência: 0.12s
# ▶️ [Mês 01] Pág: 210/7158 (2.9%) | Latência: 0.17s
# ▶️ [Mês 02] Pág: 213/7994 (2.7%) | Latência: 0.16s
# ▶️ [Mês 03] Pág: 214/8886 (2.4%) | Latência: 0.13s
# ▶️ [Mês 04] Pág: 211/9153 (2.3%) | Latência: 0.14s
# ▶️ [Mês 01] Pág: 211/7158 (2.9%) | Latência: 0.14s
# ▶️ [Mês 03] Pág: 215/8886 (2.4%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 214/7994 (2.7%) | Latência: 0.19s
# ▶️ [Mês 04] Pág: 212/9153 (2.3%) | Latência: 0.17s
# ▶️ [Mês 03] Pág: 216/8886 (2.4%) | Latência: 0.25s
# ▶️ [Mês 01] Pág: 212/7158 (3.0%) | Latência: 0.13s
# ▶️ [Mês 02] Pág: 215/7994 (2.7%) | Latência: 0.19s
# ▶️ [Mês 03] Pág: 217/8886 (2.4%) | Latência: 0.16s
# ▶️ [Mês 04] Pág: 213/9153 (2.3%) | Latência: 0.19s
# ▶️ [Mês 01] Pág: 213/7158 (3.0%) | Latência: 0.25s
# ▶️ [Mês 02] Pág: 216/7994 (2.7%) | Latência: 0.20s
# ▶️ [Mês 03] Pág: 218/8886 (2.5%) | Latência: 0.18s
# ▶️ [Mês 01] Pág: 214/7158 (3.0%) | Latência: 0.12s
# ▶️ [Mês 04] Pág: 214/9153 (2.3%) | Latência: 0.21s
# ▶️ [Mês 01] Pág: 215/7158 (3.0%) | Latência: 0.16s
# ▶️ [Mês 04] Pág: 215/9153 (2.3%) | Latência: 0.17s
# ▶️ [Mês 02] Pág: 217/7994 (2.7%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 219/8886 (2.5%) | Latência: 0.17s
# ▶️ [Mês 01] Pág: 216/7158 (3.0%) | Latência: 0.16s
# ▶️ [Mês 02] Pág: 218/7994 (2.7%) | Latência: 0.19s
# ▶️ [Mês 03] Pág: 220/8886 (2.5%) | Latência: 0.16s
# ▶️ [Mês 04] Pág: 216/9153 (2.4%) | Latência: 0.28s
# ▶️ [Mês 01] Pág: 217/7158 (3.0%) | Latência: 0.33s
# ▶️ [Mês 02] Pág: 219/7994 (2.7%) | Latência: 0.14s
# ▶️ [Mês 03] Pág: 221/8886 (2.5%) | Latência: 0.28s
# ▶️ [Mês 04] Pág: 217/9153 (2.4%) | Latência: 0.32s
# ▶️ [Mês 02] Pág: 220/7994 (2.8%) | Latência: 0.13s
# ▶️ [Mês 01] Pág: 218/7158 (3.0%) | Latência: 0.12s
# ▶️ [Mês 04] Pág: 218/9153 (2.4%) | Latência: 0.13s
# ▶️ [Mês 01] Pág: 219/7158 (3.1%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 221/7994 (2.8%) | Latência: 0.07s
# ▶️ [Mês 03] Pág: 222/8886 (2.5%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 219/9153 (2.4%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 220/7158 (3.1%) | Latência: 0.07s
# ▶️ [Mês 03] Pág: 223/8886 (2.5%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 222/7994 (2.8%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 220/9153 (2.4%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 221/7158 (3.1%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 223/7994 (2.8%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 224/8886 (2.5%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 221/9153 (2.4%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 222/7158 (3.1%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 224/7994 (2.8%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 223/7158 (3.1%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 222/9153 (2.4%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 225/8886 (2.5%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 225/7994 (2.8%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 224/7158 (3.1%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 223/9153 (2.4%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 226/8886 (2.5%) | Latência: 0.07s
# ▶️ [Mês 02] Pág: 226/7994 (2.8%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 224/9153 (2.4%) | Latência: 0.17s
# ▶️ [Mês 01] Pág: 225/7158 (3.1%) | Latência: 0.07s
# ▶️ [Mês 03] Pág: 227/8886 (2.6%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 227/7994 (2.8%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 225/9153 (2.5%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 228/8886 (2.6%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 226/7158 (3.2%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 228/7994 (2.9%) | Latência: 0.13s
# ▶️ [Mês 04] Pág: 226/9153 (2.5%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 229/8886 (2.6%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 227/7158 (3.2%) | Latência: 0.16s
# ▶️ [Mês 02] Pág: 229/7994 (2.9%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 228/7158 (3.2%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 227/9153 (2.5%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 230/8886 (2.6%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 230/7994 (2.9%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 229/7158 (3.2%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 231/8886 (2.6%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 228/9153 (2.5%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 231/7994 (2.9%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 232/8886 (2.6%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 230/7158 (3.2%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 232/7994 (2.9%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 229/9153 (2.5%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 233/8886 (2.6%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 231/7158 (3.2%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 233/7994 (2.9%) | Latência: 0.13s
# ▶️ [Mês 04] Pág: 230/9153 (2.5%) | Latência: 0.13s
# ▶️ [Mês 01] Pág: 232/7158 (3.2%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 234/8886 (2.6%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 234/7994 (2.9%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 235/8886 (2.6%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 231/9153 (2.5%) | Latência: 0.14s
# ▶️ [Mês 01] Pág: 233/7158 (3.3%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 235/7994 (2.9%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 232/9153 (2.5%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 236/8886 (2.7%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 234/7158 (3.3%) | Latência: 0.07s
# ▶️ [Mês 04] Pág: 233/9153 (2.5%) | Latência: 0.13s
# ▶️ [Mês 03] Pág: 237/8886 (2.7%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 235/7158 (3.3%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 236/7994 (3.0%) | Latência: 0.14s
# ▶️ [Mês 01] Pág: 236/7158 (3.3%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 234/9153 (2.6%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 238/8886 (2.7%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 237/7994 (3.0%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 237/7158 (3.3%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 235/9153 (2.6%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 238/7158 (3.3%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 238/7994 (3.0%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 239/8886 (2.7%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 239/7994 (3.0%) | Latência: 0.07s
# ▶️ [Mês 01] Pág: 239/7158 (3.3%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 236/9153 (2.6%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 240/8886 (2.7%) | Latência: 0.07s
# ▶️ [Mês 02] Pág: 240/7994 (3.0%) | Latência: 0.07s
# ▶️ [Mês 03] Pág: 241/8886 (2.7%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 237/9153 (2.6%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 240/7158 (3.4%) | Latência: 0.07s
# ▶️ [Mês 02] Pág: 241/7994 (3.0%) | Latência: 0.07s
# ▶️ [Mês 01] Pág: 241/7158 (3.4%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 242/8886 (2.7%) | Latência: 0.07s
# ▶️ [Mês 04] Pág: 238/9153 (2.6%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 242/7994 (3.0%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 243/7994 (3.0%) | Latência: 0.13s
# ▶️ [Mês 03] Pág: 243/8886 (2.7%) | Latência: 0.11s
# ▶️ [Mês 04] Pág: 239/9153 (2.6%) | Latência: 0.07s
# ▶️ [Mês 01] Pág: 242/7158 (3.4%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 240/9153 (2.6%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 243/7158 (3.4%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 244/7994 (3.1%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 244/8886 (2.7%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 241/9153 (2.6%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 245/7994 (3.1%) | Latência: 0.49s
# ▶️ [Mês 01] Pág: 244/7158 (3.4%) | Latência: 0.07s
# ▶️ [Mês 03] Pág: 245/8886 (2.8%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 242/9153 (2.6%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 246/7994 (3.1%) | Latência: 0.36s
# ▶️ [Mês 01] Pág: 245/7158 (3.4%) | Latência: 0.19s
# ▶️ [Mês 04] Pág: 243/9153 (2.7%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 246/8886 (2.8%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 246/7158 (3.4%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 244/9153 (2.7%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 247/7994 (3.1%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 247/8886 (2.8%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 247/7158 (3.5%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 245/9153 (2.7%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 248/7158 (3.5%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 248/8886 (2.8%) | Latência: 0.12s
# ▶️ [Mês 02] Pág: 248/7994 (3.1%) | Latência: 0.16s
# ▶️ [Mês 04] Pág: 246/9153 (2.7%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 249/7158 (3.5%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 249/8886 (2.8%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 249/7994 (3.1%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 247/9153 (2.7%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 250/7158 (3.5%) | Latência: 1.64s
# 💾 [Mês 01] CHECKPOINT: 1000 itens salvos. (Hora: 16:48:27)
# ▶️ [Mês 02] Pág: 250/7994 (3.1%) | Latência: 1.59s
# 💾 [Mês 02] CHECKPOINT: 1000 itens salvos. (Hora: 16:48:27)
# ▶️ [Mês 03] Pág: 250/8886 (2.8%) | Latência: 0.78s
# 💾 [Mês 03] CHECKPOINT: 1000 itens salvos. (Hora: 16:48:27)
# ▶️ [Mês 04] Pág: 248/9153 (2.7%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 249/9153 (2.7%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 251/7994 (3.1%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 251/7158 (3.5%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 251/8886 (2.8%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 250/9153 (2.7%) | Latência: 0.09s
# 💾 [Mês 04] CHECKPOINT: 1000 itens salvos. (Hora: 16:48:30)
# ▶️ [Mês 03] Pág: 252/8886 (2.8%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 252/7994 (3.2%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 252/7158 (3.5%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 251/9153 (2.7%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 253/7994 (3.2%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 253/8886 (2.8%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 253/7158 (3.5%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 252/9153 (2.8%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 254/7994 (3.2%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 254/8886 (2.9%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 253/9153 (2.8%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 254/7158 (3.5%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 255/8886 (2.9%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 255/7994 (3.2%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 255/7158 (3.6%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 256/7994 (3.2%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 254/9153 (2.8%) | Latência: 0.15s
# ▶️ [Mês 03] Pág: 256/8886 (2.9%) | Latência: 0.15s
# ▶️ [Mês 04] Pág: 255/9153 (2.8%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 256/7158 (3.6%) | Latência: 0.07s
# ▶️ [Mês 02] Pág: 257/7994 (3.2%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 257/8886 (2.9%) | Latência: 0.14s
# ▶️ [Mês 04] Pág: 256/9153 (2.8%) | Latência: 0.07s
# ▶️ [Mês 04] Pág: 257/9153 (2.8%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 257/7158 (3.6%) | Latência: 0.07s
# ▶️ [Mês 02] Pág: 258/7994 (3.2%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 258/8886 (2.9%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 258/7158 (3.6%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 259/7994 (3.2%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 258/9153 (2.8%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 259/8886 (2.9%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 260/8886 (2.9%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 260/7994 (3.3%) | Latência: 0.07s
# ▶️ [Mês 04] Pág: 259/9153 (2.8%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 259/7158 (3.6%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 261/7994 (3.3%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 261/8886 (2.9%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 260/9153 (2.8%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 260/7158 (3.6%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 262/8886 (2.9%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 261/7158 (3.6%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 262/7994 (3.3%) | Latência: 0.07s
# ▶️ [Mês 04] Pág: 261/9153 (2.9%) | Latência: 0.17s
# ▶️ [Mês 03] Pág: 263/8886 (3.0%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 262/9153 (2.9%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 262/7158 (3.7%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 263/7994 (3.3%) | Latência: 0.07s
# ▶️ [Mês 04] Pág: 263/9153 (2.9%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 263/7158 (3.7%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 264/8886 (3.0%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 264/7994 (3.3%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 264/7158 (3.7%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 265/8886 (3.0%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 264/9153 (2.9%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 265/7994 (3.3%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 265/7158 (3.7%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 266/8886 (3.0%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 265/9153 (2.9%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 266/7994 (3.3%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 266/7158 (3.7%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 267/7994 (3.3%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 267/8886 (3.0%) | Latência: 0.07s
# ▶️ [Mês 04] Pág: 266/9153 (2.9%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 267/7158 (3.7%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 268/8886 (3.0%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 268/7994 (3.4%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 267/9153 (2.9%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 268/7158 (3.7%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 269/8886 (3.0%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 269/7994 (3.4%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 270/8886 (3.0%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 268/9153 (2.9%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 269/7158 (3.8%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 271/8886 (3.0%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 270/7994 (3.4%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 269/9153 (2.9%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 272/8886 (3.1%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 270/7158 (3.8%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 271/7994 (3.4%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 270/9153 (2.9%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 273/8886 (3.1%) | Latência: 0.16s
# ▶️ [Mês 02] Pág: 272/7994 (3.4%) | Latência: 0.07s
# ▶️ [Mês 01] Pág: 271/7158 (3.8%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 273/7994 (3.4%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 271/9153 (3.0%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 274/8886 (3.1%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 272/7158 (3.8%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 274/7994 (3.4%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 272/9153 (3.0%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 273/7158 (3.8%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 275/7994 (3.4%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 275/8886 (3.1%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 273/9153 (3.0%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 276/7994 (3.5%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 276/8886 (3.1%) | Latência: 0.12s
# ▶️ [Mês 01] Pág: 274/7158 (3.8%) | Latência: 0.11s
# ▶️ [Mês 04] Pág: 274/9153 (3.0%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 277/7994 (3.5%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 275/7158 (3.8%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 275/9153 (3.0%) | Latência: 0.13s
# ▶️ [Mês 03] Pág: 277/8886 (3.1%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 276/9153 (3.0%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 278/8886 (3.1%) | Latência: 0.12s
# ▶️ [Mês 02] Pág: 278/7994 (3.5%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 276/7158 (3.9%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 279/7994 (3.5%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 277/9153 (3.0%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 279/8886 (3.1%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 277/7158 (3.9%) | Latência: 0.07s
# ▶️ [Mês 04] Pág: 278/9153 (3.0%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 280/7994 (3.5%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 278/7158 (3.9%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 280/8886 (3.2%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 279/9153 (3.0%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 281/7994 (3.5%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 279/7158 (3.9%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 281/8886 (3.2%) | Latência: 0.07s
# ▶️ [Mês 02] Pág: 282/7994 (3.5%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 280/9153 (3.1%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 283/7994 (3.5%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 282/8886 (3.2%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 280/7158 (3.9%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 281/9153 (3.1%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 284/7994 (3.6%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 282/9153 (3.1%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 283/8886 (3.2%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 281/7158 (3.9%) | Latência: 0.13s
# ▶️ [Mês 04] Pág: 283/9153 (3.1%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 285/7994 (3.6%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 284/8886 (3.2%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 282/7158 (3.9%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 284/9153 (3.1%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 286/7994 (3.6%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 285/8886 (3.2%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 285/9153 (3.1%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 287/7994 (3.6%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 283/7158 (4.0%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 286/8886 (3.2%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 287/8886 (3.2%) | Latência: 0.12s
# ▶️ [Mês 02] Pág: 288/7994 (3.6%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 286/9153 (3.1%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 284/7158 (4.0%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 287/9153 (3.1%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 288/8886 (3.2%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 289/7994 (3.6%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 285/7158 (4.0%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 289/8886 (3.3%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 290/7994 (3.6%) | Latência: 0.12s
# ▶️ [Mês 01] Pág: 286/7158 (4.0%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 288/9153 (3.1%) | Latência: 0.14s
# ▶️ [Mês 02] Pág: 291/7994 (3.6%) | Latência: 0.12s
# ▶️ [Mês 03] Pág: 290/8886 (3.3%) | Latência: 0.18s
# ▶️ [Mês 01] Pág: 287/7158 (4.0%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 289/9153 (3.2%) | Latência: 0.15s
# ▶️ [Mês 02] Pág: 292/7994 (3.7%) | Latência: 0.12s
# ▶️ [Mês 03] Pág: 291/8886 (3.3%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 293/7994 (3.7%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 288/7158 (4.0%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 290/9153 (3.2%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 292/8886 (3.3%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 289/7158 (4.0%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 294/7994 (3.7%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 290/7158 (4.1%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 291/9153 (3.2%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 293/8886 (3.3%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 295/7994 (3.7%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 291/7158 (4.1%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 292/9153 (3.2%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 296/7994 (3.7%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 294/8886 (3.3%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 292/7158 (4.1%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 293/9153 (3.2%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 293/7158 (4.1%) | Latência: 0.23s
# ▶️ [Mês 02] Pág: 297/7994 (3.7%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 294/9153 (3.2%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 295/8886 (3.3%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 294/7158 (4.1%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 296/8886 (3.3%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 295/9153 (3.2%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 298/7994 (3.7%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 295/7158 (4.1%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 296/9153 (3.2%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 299/7994 (3.7%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 297/8886 (3.3%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 296/7158 (4.1%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 298/8886 (3.4%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 297/9153 (3.2%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 300/7994 (3.8%) | Latência: 0.09s
# 💾 [Mês 02] CHECKPOINT: 1000 itens salvos. (Hora: 16:49:57)
# ▶️ [Mês 01] Pág: 297/7158 (4.1%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 299/8886 (3.4%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 301/7994 (3.8%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 298/9153 (3.3%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 298/7158 (4.2%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 300/8886 (3.4%) | Latência: 0.11s
# 💾 [Mês 03] CHECKPOINT: 1000 itens salvos. (Hora: 16:50:00)
# ▶️ [Mês 02] Pág: 302/7994 (3.8%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 299/7158 (4.2%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 299/9153 (3.3%) | Latência: 0.12s
# ▶️ [Mês 02] Pág: 303/7994 (3.8%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 301/8886 (3.4%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 300/7158 (4.2%) | Latência: 0.08s
# 💾 [Mês 01] CHECKPOINT: 1000 itens salvos. (Hora: 16:50:03)
# ▶️ [Mês 02] Pág: 304/7994 (3.8%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 300/9153 (3.3%) | Latência: 0.11s
# 💾 [Mês 04] CHECKPOINT: 1000 itens salvos. (Hora: 16:50:04)
# ▶️ [Mês 01] Pág: 301/7158 (4.2%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 302/8886 (3.4%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 301/9153 (3.3%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 305/7994 (3.8%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 302/7158 (4.2%) | Latência: 0.11s
# ▶️ [Mês 04] Pág: 302/9153 (3.3%) | Latência: 0.11s
# ▶️ [Mês 03] Pág: 303/8886 (3.4%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 306/7994 (3.8%) | Latência: 0.12s
# ▶️ [Mês 01] Pág: 303/7158 (4.2%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 303/9153 (3.3%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 307/7994 (3.8%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 304/8886 (3.4%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 304/9153 (3.3%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 304/7158 (4.2%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 305/9153 (3.3%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 305/7158 (4.3%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 308/7994 (3.9%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 305/8886 (3.4%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 309/7994 (3.9%) | Latência: 0.12s
# ▶️ [Mês 01] Pág: 306/7158 (4.3%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 306/9153 (3.3%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 306/8886 (3.4%) | Latência: 0.07s
# ▶️ [Mês 02] Pág: 310/7994 (3.9%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 307/9153 (3.4%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 307/7158 (4.3%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 307/8886 (3.5%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 308/9153 (3.4%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 308/8886 (3.5%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 311/7994 (3.9%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 308/7158 (4.3%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 309/8886 (3.5%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 312/7994 (3.9%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 309/9153 (3.4%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 310/8886 (3.5%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 313/7994 (3.9%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 309/7158 (4.3%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 311/8886 (3.5%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 310/9153 (3.4%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 310/7158 (4.3%) | Latência: 0.11s
# ▶️ [Mês 03] Pág: 312/8886 (3.5%) | Latência: 0.13s
# ▶️ [Mês 02] Pág: 314/7994 (3.9%) | Latência: 0.15s
# ▶️ [Mês 04] Pág: 311/9153 (3.4%) | Latência: 0.20s
# ▶️ [Mês 01] Pág: 311/7158 (4.3%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 313/8886 (3.5%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 312/9153 (3.4%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 315/7994 (3.9%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 312/7158 (4.4%) | Latência: 0.13s
# ▶️ [Mês 04] Pág: 313/9153 (3.4%) | Latência: 0.12s
# ▶️ [Mês 03] Pág: 314/8886 (3.5%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 316/7994 (4.0%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 313/7158 (4.4%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 315/8886 (3.5%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 314/7158 (4.4%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 314/9153 (3.4%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 317/7994 (4.0%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 316/8886 (3.6%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 318/7994 (4.0%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 315/9153 (3.4%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 315/7158 (4.4%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 317/8886 (3.6%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 319/7994 (4.0%) | Latência: 0.13s
# ▶️ [Mês 03] Pág: 318/8886 (3.6%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 316/7158 (4.4%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 316/9153 (3.5%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 320/7994 (4.0%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 317/7158 (4.4%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 319/8886 (3.6%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 317/9153 (3.5%) | Latência: 0.12s
# ▶️ [Mês 01] Pág: 318/7158 (4.4%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 320/8886 (3.6%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 321/7994 (4.0%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 321/8886 (3.6%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 318/9153 (3.5%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 319/7158 (4.5%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 322/7994 (4.0%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 322/8886 (3.6%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 319/9153 (3.5%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 323/7994 (4.0%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 320/7158 (4.5%) | Latência: 0.11s
# ▶️ [Mês 03] Pág: 323/8886 (3.6%) | Latência: 0.11s
# ▶️ [Mês 04] Pág: 320/9153 (3.5%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 321/7158 (4.5%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 324/7994 (4.1%) | Latência: 0.11s
# ▶️ [Mês 03] Pág: 324/8886 (3.6%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 322/7158 (4.5%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 321/9153 (3.5%) | Latência: 0.14s
# ▶️ [Mês 02] Pág: 325/7994 (4.1%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 325/8886 (3.7%) | Latência: 0.11s
# ▶️ [Mês 04] Pág: 322/9153 (3.5%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 326/7994 (4.1%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 323/7158 (4.5%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 323/9153 (3.5%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 326/8886 (3.7%) | Latência: 0.12s
# ▶️ [Mês 02] Pág: 327/7994 (4.1%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 324/7158 (4.5%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 324/9153 (3.5%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 327/8886 (3.7%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 328/7994 (4.1%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 325/7158 (4.5%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 329/7994 (4.1%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 328/8886 (3.7%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 325/9153 (3.6%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 326/9153 (3.6%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 326/7158 (4.6%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 330/7994 (4.1%) | Latência: 0.12s
# ▶️ [Mês 03] Pág: 329/8886 (3.7%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 327/9153 (3.6%) | Latência: 0.11s
# ▶️ [Mês 03] Pág: 330/8886 (3.7%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 327/7158 (4.6%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 331/7994 (4.1%) | Latência: 0.11s
# ▶️ [Mês 03] Pág: 331/8886 (3.7%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 328/7158 (4.6%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 328/9153 (3.6%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 332/7994 (4.2%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 333/7994 (4.2%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 332/8886 (3.7%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 329/7158 (4.6%) | Latência: 0.11s
# ▶️ [Mês 04] Pág: 329/9153 (3.6%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 334/7994 (4.2%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 330/9153 (3.6%) | Latência: 0.12s
# ▶️ [Mês 03] Pág: 333/8886 (3.7%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 330/7158 (4.6%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 331/9153 (3.6%) | Latência: 0.20s
# ▶️ [Mês 02] Pág: 335/7994 (4.2%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 331/7158 (4.6%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 334/8886 (3.8%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 336/7994 (4.2%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 332/9153 (3.6%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 337/7994 (4.2%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 332/7158 (4.6%) | Latência: 0.11s
# ▶️ [Mês 03] Pág: 335/8886 (3.8%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 333/9153 (3.6%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 338/7994 (4.2%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 333/7158 (4.7%) | Latência: 0.07s
# ▶️ [Mês 03] Pág: 336/8886 (3.8%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 334/9153 (3.6%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 334/7158 (4.7%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 339/7994 (4.2%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 335/9153 (3.7%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 337/8886 (3.8%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 335/7158 (4.7%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 340/7994 (4.3%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 338/8886 (3.8%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 336/9153 (3.7%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 336/7158 (4.7%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 337/9153 (3.7%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 341/7994 (4.3%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 339/8886 (3.8%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 337/7158 (4.7%) | Latência: 0.11s
# ▶️ [Mês 03] Pág: 340/8886 (3.8%) | Latência: 0.08s
# ▶️ [Mês 02] Pág: 342/7994 (4.3%) | Latência: 0.08s
# ▶️ [Mês 04] Pág: 338/9153 (3.7%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 341/8886 (3.8%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 338/7158 (4.7%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 343/7994 (4.3%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 339/9153 (3.7%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 339/7158 (4.7%) | Latência: 0.12s
# ▶️ [Mês 03] Pág: 342/8886 (3.8%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 344/7994 (4.3%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 340/9153 (3.7%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 340/7158 (4.7%) | Latência: 0.11s
# ▶️ [Mês 04] Pág: 341/9153 (3.7%) | Latência: 0.15s
# ▶️ [Mês 03] Pág: 343/8886 (3.9%) | Latência: 0.14s
# ▶️ [Mês 02] Pág: 345/7994 (4.3%) | Latência: 0.14s
# ▶️ [Mês 01] Pág: 341/7158 (4.8%) | Latência: 0.12s
# ▶️ [Mês 03] Pág: 344/8886 (3.9%) | Latência: 0.14s
# ▶️ [Mês 04] Pág: 342/9153 (3.7%) | Latência: 0.14s
# ▶️ [Mês 02] Pág: 346/7994 (4.3%) | Latência: 0.13s
# ▶️ [Mês 03] Pág: 345/8886 (3.9%) | Latência: 0.15s
# ▶️ [Mês 01] Pág: 342/7158 (4.8%) | Latência: 0.13s
# ▶️ [Mês 02] Pág: 347/7994 (4.3%) | Latência: 0.11s
# ▶️ [Mês 03] Pág: 346/8886 (3.9%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 343/9153 (3.7%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 348/7994 (4.4%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 343/7158 (4.8%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 347/8886 (3.9%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 349/7994 (4.4%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 344/9153 (3.8%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 344/7158 (4.8%) | Latência: 0.08s
# ▶️ [Mês 03] Pág: 348/8886 (3.9%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 350/7994 (4.4%) | Latência: 0.13s
# 💾 [Mês 02] CHECKPOINT: 1000 itens salvos. (Hora: 16:51:30)
# ▶️ [Mês 04] Pág: 345/9153 (3.8%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 349/8886 (3.9%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 345/7158 (4.8%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 350/8886 (3.9%) | Latência: 0.09s
# 💾 [Mês 03] CHECKPOINT: 1000 itens salvos. (Hora: 16:51:32)
# ▶️ [Mês 02] Pág: 351/7994 (4.4%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 346/7158 (4.8%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 346/9153 (3.8%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 351/8886 (4.0%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 347/7158 (4.8%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 347/9153 (3.8%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 352/7994 (4.4%) | Latência: 0.09s
# ▶️ [Mês 02] Pág: 353/7994 (4.4%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 352/8886 (4.0%) | Latência: 0.10s
# ▶️ [Mês 01] Pág: 348/7158 (4.9%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 348/9153 (3.8%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 349/7158 (4.9%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 354/7994 (4.4%) | Latência: 0.07s
# ▶️ [Mês 04] Pág: 349/9153 (3.8%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 353/8886 (4.0%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 350/7158 (4.9%) | Latência: 0.09s
# 💾 [Mês 01] CHECKPOINT: 1000 itens salvos. (Hora: 16:51:39)
# ▶️ [Mês 02] Pág: 355/7994 (4.4%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 354/8886 (4.0%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 350/9153 (3.8%) | Latência: 0.12s
# 💾 [Mês 04] CHECKPOINT: 1000 itens salvos. (Hora: 16:51:41)
# ▶️ [Mês 01] Pág: 351/7158 (4.9%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 356/7994 (4.5%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 355/8886 (4.0%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 357/7994 (4.5%) | Latência: 0.09s
# ▶️ [Mês 01] Pág: 352/7158 (4.9%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 351/9153 (3.8%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 358/7994 (4.5%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 352/9153 (3.8%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 356/8886 (4.0%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 353/7158 (4.9%) | Latência: 0.09s
# ▶️ [Mês 03] Pág: 357/8886 (4.0%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 359/7994 (4.5%) | Latência: 0.11s
# ▶️ [Mês 04] Pág: 353/9153 (3.9%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 354/7158 (4.9%) | Latência: 0.12s
# ▶️ [Mês 02] Pág: 360/7994 (4.5%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 358/8886 (4.0%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 355/7158 (5.0%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 354/9153 (3.9%) | Latência: 0.10s
# ▶️ [Mês 02] Pág: 361/7994 (4.5%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 356/7158 (5.0%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 359/8886 (4.0%) | Latência: 0.10s
# ▶️ [Mês 04] Pág: 355/9153 (3.9%) | Latência: 0.14s
# ▶️ [Mês 02] Pág: 362/7994 (4.5%) | Latência: 0.11s
# ▶️ [Mês 01] Pág: 357/7158 (5.0%) | Latência: 0.10s
# ▶️ [Mês 03] Pág: 360/8886 (4.1%) | Latência: 0.08s
# ▶️ [Mês 01] Pág: 358/7158 (5.0%) | Latência: 0.09s
# ▶️ [Mês 04] Pág: 356/9153 (3.9%) | Latência: 0.11s
# ▶️ [Mês 02] Pág: 363/7994 (4.5%) | Latência: 0.09s
